# %% [markdown]
# # TP1 de MCS

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from random import randrange
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sn
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec

# %% [markdown]
# ## Partie I

# %%
def DTW(w0, w1, w2, seq1, seq2, d):
    I, J = seq2.shape[0], seq1.shape[0]
    g = np.empty((I+1,J+1))
    g.fill(None)

    g[0][0] = 0


    for j in range(1,J+1):
        g[0][j] = np.Infinity

    for i in range(1,I+1):
        g[i][0] = np.Infinity
        for j in range(1,J+1):
            g[i][j] = min(g[i-1][j]+d(seq2[i-1],seq1[j-1])*w0, g[i-1][j-1]+d(seq2[i-1],seq1[j-1])*w1, g[i][j-1]+d(seq2[i-1],seq1[j-1])*w2)


#     print(g)
    score = g[I][J]/(I+J)
#     print(f'score: {score}')

    return score

# %% [markdown]
# Définition des fonctions de distance

# %%
D = {('X', 'X'): 0, ('X', 'C'): 1, ('X', 'U'): 1, ('X', 'U_X'): 1, ('X', 'V'): 2,
     ('C', 'X'): 1, ('C', 'C'): 0, ('C', 'U'): 1, ('C', 'U_X'): 1, ('C', 'V'): 2, 
     ('U', 'X'): 1, ('U', 'C'): 1, ('U', 'U'): 0, ('U', 'U_X'): 1, ('U', 'V'): 1, 
     ('U_X', 'X'): 1, ('U_X', 'C'): 1, ('U_X', 'U'): 1, ('U_X', 'U_X'): 0, ('U_X', 'V'): 2,
     ('V', 'X'): 2, ('V', 'C'): 2, ('V', 'U'): 1, ('V', 'U_X'): 2, ('V', 'V'): 0}


vect = lambda i, j: np.linalg.norm(i-j)
absolue = lambda i, j: abs(i-j)
euclidienne = lambda i, j: sqrt(i**2 + j**2)
adn = lambda i, j: i!=j
son = lambda i, j: D[(i,j)]

# %% [markdown]
# Test avec l'exemple du cours

# %%
seq1 = np.array([1,0,2,3])
seq2 = np.array([-1,1,0])

DTW(1, 1, 1, seq1, seq2, vect)
# Out:
# 1.0

# %% [markdown]
# Test avec l'exemple de l'exercice **2.1**

# %%
seq1 = np.array([-2,10,-10,15,-13,20,-5,14,2])
seq2 = np.array([3,-13,14,-7,9,-2])

DTW(1, 1, 1, seq1, seq2, vect)
# Out:
# 3.6

# %% [markdown]
# Test avec l'exemple de l'exercice **2.2**

# %%
seq1 = np.array(['A','T','G','G','T','A','C','G','T','C'])
seq2 = np.array(['A','A','G','T','A','G','G','C'])

DTW(1, 1, 1, seq2, seq1, adn)
# Out:
# 0.16666666666666666

# %% [markdown]
# Test avec l'exemple de l'exercice **2.3**

# %%
cinq, vingt, cent = np.array("X V V C X".split()), np.array("U_X V V".split()), np.array("X V V".split())

# %% [markdown]
# *Question 1.*

# %%
seq1 = np.array("X X V U X C X".split())

score_seq1_cinq = DTW(1, 2, 1, seq1, cinq, son)
score_seq1_vingt = DTW(1, 2, 1, seq1, vingt, son)
score_seq1_cent = DTW(1, 2, 1, seq1, cent, son)

print(score_seq1_cinq, score_seq1_vingt, score_seq1_cent)
print("Le mot 'cinq' est donc reconnu")
# Out:
# 0.25 1.0 0.7
# Le mot 'cinq' est donc reconnu

# %% [markdown]
# *Question 2.*

# %%
seq1 = np.array("U_X U_X V X X V U_X X X V".split())

score_seq1_cinq = DTW(1, 2, 1, seq1, cinq, son)
score_seq1_vingt = DTW(1, 2, 1, seq1, vingt, son)
score_seq1_cent = DTW(1, 2, 1, seq1, cent, son)

print(score_seq1_cinq, score_seq1_vingt, score_seq1_cent)
print("En théorie le mot 'cinq' est reconnu mais ils ont tous quasiment le même score")
# Out:
# 0.6 0.6153846153846154 0.6153846153846154
# En théorie le mot 'cinq' est reconnu mais ils ont tous quasiment le même score

# %% [markdown]
# ## Partie II

# %%
import librosa

# %%
m1, sr_m1 = librosa.load("corpus_test/M01_arretetoi.wav")
f1, sr_f1 = librosa.load("corpus_dgo/non_bruite/M20_arretetoi.wav")

mfcc_m1 = librosa.feature.mfcc(y=m1, sr=sr_m1, hop_length=1024, htk=True,
n_mfcc=12)
mfcc_f1 = librosa.feature.mfcc(y=f1, sr=sr_f1, hop_length=1024, htk=True,
n_mfcc=12)

# %%
print(mfcc_m1.transpose().shape)
print(mfcc_m1.transpose())
# Out:
# (23, 12)
# [[-5.69067566e+02  3.96389389e+01  1.16038837e+01 -2.67735630e-01
#    9.88271117e-01  2.37937379e+00  1.00877911e-01  6.42509699e-01
#    2.86828935e-01  8.91457915e-01  2.99287844e+00  1.82023382e+00]
#  [-5.58488953e+02  4.44846840e+01  1.02761135e+01  3.52746105e+00
#    4.30340958e+00  3.58957005e+00 -1.47373724e+00 -5.46282768e+00
#   -5.81379318e+00 -1.21794951e+00 -2.13599253e+00 -6.74367237e+00]
#  [-5.27500610e+02  6.16945305e+01 -6.19593811e+00 -1.68548317e+01
#   -1.18617070e+00  1.41989088e+01  5.13344002e+00 -8.81754303e+00
#   -1.06254606e+01 -1.73280716e+00  3.70688725e+00 -2.25795197e+00]
#  [-3.69334015e+02  1.60807571e+02  4.36984825e+00 -2.24313679e+01
#   -3.25781326e+01  2.81653252e+01 -2.95342296e-01 -1.72252369e+01
#   -6.89808726e-01 -1.46516647e+01 -5.96900082e+00  1.61949527e+00]
#  [-2.19406464e+02  2.12065399e+02 -4.60909195e+01 -2.36441422e+01
#   -4.77081985e+01  1.98847046e+01 -1.79825325e+01 -2.40556965e+01
#    3.44541121e+00 -2.67376785e+01 -2.82614899e+00  1.70961201e-01]
#  [-1.82209167e+02  2.04452576e+02 -7.56223297e+01 -1.27354317e+01
#   -6.01669464e+01  3.13870382e+00 -1.89020538e+01 -8.04249859e+00
#    2.30462856e+01 -3.70757980e+01 -1.60826552e+00  5.44090986e+00]
#  [-1.64051407e+02  2.19586731e+02 -8.11134872e+01 -1.31492958e+01
#   -4.16172562e+01 -8.58695602e+00 -2.86465836e+01  6.73675346e+00
#    1.16692638e+01 -3.65085716e+01  1.40067225e+01  1.74636402e+01]
#  [-1.45486603e+02  1.93797638e+02 -9.55802689e+01  7.79702139e+00
#   -1.95663223e+01  3.46618581e+00 -5.96591606e+01 -1.32154074e+01
#   -1.16504574e+01 -2.65131264e+01  2.94225159e+01 -1.36118484e+00]
#  [-2.55405716e+02  1.95043243e+02 -3.32416801e+01  2.00073776e+01
#    6.23747015e+00  3.63905954e+00 -4.67422333e+01 -2.61129208e+01
#   -1.60498142e+01 -2.40255585e+01  1.65892353e+01 -2.18897343e+00]
#  [-1.86170334e+02  1.34799210e+02 -6.03609428e+01  5.11267166e+01
#   -5.31894760e+01  1.76730156e+01 -3.82782059e+01 -2.14499416e+01
#   -2.32838726e+00 -9.59605217e+00  8.53600919e-01 -1.60734673e+01]
#  [-2.00558594e+02  2.12794479e+02 -4.71732864e+01  2.98792248e+01
#   -2.26954579e+00 -6.73204720e-01 -3.74398842e+01 -2.94261627e+01
#   -3.14060802e+01 -4.51925125e+01  3.45542908e+00  6.45262051e+00]
#  [-3.53839020e+02  1.73895554e+02  3.48002219e+00  2.58179588e+01
#    1.31024103e+01 -6.56958818e+00 -2.02539673e+01 -2.09829540e+01
#   -2.86723442e+01 -3.14752808e+01 -3.18881798e+00  4.45482731e+00]
#  [-2.29784973e+02  1.15550682e+02 -7.18784332e+01  3.23525314e+01
#   -4.48166046e+01  2.41786613e+01 -2.22526932e+01 -1.03732815e+01
#   -1.42373333e+01 -1.94093170e+01  1.16349850e+01 -5.47824192e+00]
#  [-2.43490768e+02  2.07360657e+02 -5.49251366e+00  1.67190762e+01
#   -2.69801216e+01  1.59447231e+01 -1.89402390e+01 -1.22161865e+01
#   -8.39368439e+00 -2.60855885e+01 -7.91610718e+00 -6.59510517e+00]
#  [-2.74923920e+02  2.28847000e+02 -2.35426855e+00  5.30034399e+00
#   -3.14200878e+01 -4.29226494e+01 -3.04420891e+01 -1.10182390e+01
#    7.49593794e-01 -2.44164886e+01 -2.11219826e+01 -5.31140709e+00]
#  [-2.49543472e+02  2.22028229e+02 -2.27377853e+01 -7.37034702e+00
#   -4.46185074e+01 -1.97465782e+01 -2.67700500e+01 -1.50670938e+01
#    1.41795483e+01 -3.08146744e+01 -1.74150677e+01  1.06007309e+01]
#  [-2.55174438e+02  2.18146301e+02 -2.56454735e+01 -1.39373436e+01
#   -4.42253189e+01 -1.05049648e+01 -2.02632217e+01 -2.00036564e+01
#    1.04630795e+01 -3.03005371e+01 -1.91486053e+01  1.60936298e+01]
#  [-2.87392853e+02  1.94124146e+02 -3.07829857e+00 -1.37158318e+01
#   -5.12613907e+01  9.65843773e+00 -2.05066223e+01 -1.12231283e+01
#    8.10533428e+00 -2.97419167e+01 -1.16009331e+01  7.06074333e+00]
#  [-3.99731628e+02  1.40013794e+02  2.07444172e+01  9.76266670e+00
#   -1.81121044e+01  7.15595150e+00 -1.18429756e+01  4.88637781e+00
#    7.10303736e+00 -2.27310371e+01 -7.18063831e+00  9.08578110e+00]
#  [-4.86013763e+02  1.10024536e+02  1.89270020e+01 -6.28946304e+00
#   -8.67620277e+00 -8.40690899e+00  7.34308958e-01  1.32089645e-01
#   -9.15798378e+00 -6.10381651e+00  2.14291120e+00  5.43997288e+00]
#  [-5.15204102e+02  8.38239136e+01  1.47319088e+01 -1.61426890e+00
#   -4.53819466e+00 -1.05557480e+01 -3.77456498e+00 -3.75561714e-02
#   -6.21915340e+00 -6.42278957e+00 -1.05151093e+00  5.20056343e+00]
#  [-5.24316345e+02  7.77365646e+01  1.57664089e+01 -9.72930193e-02
#   -9.79901254e-02 -4.87047482e+00 -3.22619224e+00 -1.22887230e+00
#   -3.67538404e+00 -3.47384882e+00 -2.91965270e+00 -3.37834454e+00]
#  [-5.41033142e+02  6.38548889e+01  1.45207691e+01 -2.00979114e+00
#   -1.30438423e+00 -1.91450667e+00 -2.59901690e+00 -2.46415591e+00
#   -3.62105703e+00 -2.31495881e+00 -3.60830522e+00 -3.48458076e+00]]

# %%
print(mfcc_f1)
# Out:
# [[-6.18828613e+02 -6.07766052e+02 -6.18259277e+02 -6.13610901e+02
#   -3.16548065e+02 -1.89557358e+02 -1.98688873e+02 -1.70788315e+02
#   -1.54636597e+02 -2.33654144e+02 -3.22669006e+02 -2.58229187e+02
#   -1.61193558e+02 -2.27790421e+02 -2.21338882e+02 -2.35526108e+02
#   -3.12782288e+02 -3.88017548e+02 -4.13069916e+02 -4.34809021e+02
#   -4.60775696e+02 -5.78447937e+02]
#  [ 0.00000000e+00  1.50993252e+01  7.91183054e-01  7.29091406e+00
#    1.72136826e+02  1.86211761e+02  1.73236328e+02  1.78295349e+02
#    1.75579834e+02  1.68052597e+02  1.55477570e+02  1.04072968e+02
#    1.51757416e+02  2.08314041e+02  1.93034912e+02  2.14628906e+02
#    1.81912155e+02  1.71293106e+02  1.57398209e+02  1.44030457e+02
#    1.24804886e+02  4.72604294e+01]
#  [ 0.00000000e+00  1.35412369e+01  7.49960542e-01  7.03175545e+00
#   -3.12838535e+01 -6.56323700e+01 -5.24264374e+01 -6.96221466e+01
#   -8.17521210e+01 -3.60614510e+01 -2.51696396e+01 -6.37107315e+01
#   -6.00957718e+01 -2.66189976e+01 -3.17959900e+01 -2.68666897e+01
#   -1.44372978e+01  5.45917034e+00  9.98332214e+00  1.87703705e+01
#    1.90129204e+01  2.44033318e+01]
#  [ 0.00000000e+00  1.11904964e+01  6.83032632e-01  6.61634159e+00
#   -6.00747871e+00  5.97896671e+00  1.48358364e+01  1.47305613e+01
#    2.73281212e+01  3.62187080e+01  1.30232840e+01  5.67564621e+01
#    5.12655258e+01  8.60733604e+00  1.15459461e+01 -7.14425230e+00
#    4.01343060e+00 -1.23219471e+01 -1.13758955e+01 -2.58463335e+00
#    1.91451073e-01  2.66817188e+00]
#  [ 0.00000000e+00  8.36701393e+00  5.92988133e-01  6.06828308e+00
#   -1.83681602e+01 -5.02460632e+01 -6.37540970e+01 -5.46361580e+01
#   -2.24115505e+01 -3.23172989e+01 -2.79867477e+01 -3.35918884e+01
#   -4.13963394e+01 -3.67982903e+01 -4.49205704e+01 -3.95905991e+01
#   -4.46110229e+01 -3.19448509e+01 -2.87444153e+01 -1.68737717e+01
#   -1.48679371e+01 -7.88876104e+00]
#  [ 0.00000000e+00  5.43146276e+00  4.83299464e-01  5.41835356e+00
#   -4.72867346e+00  1.12074590e+00  2.94073033e+00  1.23406947e+00
#    7.32684278e+00  1.97891986e+00 -1.45569878e+01 -5.32396889e+00
#    9.58684158e+00 -4.31121826e+01 -2.97439880e+01 -3.02670708e+01
#   -3.20652313e+01 -3.20249329e+01 -2.81050358e+01 -1.83439484e+01
#   -1.82982254e+01 -7.15489483e+00]
#  [ 0.00000000e+00  2.72152543e+00  3.58164430e-01  4.70246124e+00
#   -1.29986362e+01 -2.89840355e+01 -2.32400398e+01 -3.91785812e+01
#   -6.81656876e+01 -4.58920135e+01 -2.64370918e+01 -2.65196609e+01
#   -3.58895988e+01 -4.24155884e+01 -3.90197868e+01 -3.34953575e+01
#   -3.77828550e+00 -7.81065941e+00 -7.02561569e+00 -1.37655296e+01
#   -1.61041451e+01 -1.41162944e+00]
#  [ 0.00000000e+00  4.96973306e-01  2.22345099e-01  3.95921636e+00
#    1.56822433e+01  1.66678352e+01  1.27215519e+01  2.10240841e+00
#   -2.27676868e+00 -3.29826050e+01 -2.50736256e+01 -9.48533297e-01
#   -1.05182052e+00  2.70033588e+01  3.28626099e+01  2.67856941e+01
#    9.14292908e+00  3.14767528e+00  3.58889222e+00 -4.00573254e+00
#   -8.23993266e-01  3.56509638e+00]
#  [ 0.00000000e+00 -1.09563863e+00  8.09573457e-02  3.22741890e+00
#   -1.58665819e+01 -1.97219791e+01 -1.96597805e+01 -2.37888260e+01
#   -2.18959599e+01 -2.81698112e+01 -2.18758812e+01 -1.84095154e+01
#   -4.98059769e+01 -4.15876579e+01 -3.63062019e+01 -3.54768753e+01
#   -2.59605312e+01 -1.73658257e+01 -1.21517887e+01 -1.11874123e+01
#   -6.94427311e-01  5.73267031e+00]
#  [ 0.00000000e+00 -2.03272605e+00 -6.07271679e-02  2.54349780e+00
#   -2.76952782e+01 -4.65739136e+01 -4.17426262e+01 -3.31706619e+01
#   -2.77111683e+01 -2.21350365e+01 -8.65836334e+00 -3.81418896e+00
#   -2.57372131e+01 -4.24673233e+01 -4.18919144e+01 -3.77305450e+01
#   -2.46129761e+01 -2.01618958e+01 -1.47888737e+01 -7.39283371e+00
#   -7.77601361e-01  5.64101410e+00]
#  [ 0.00000000e+00 -2.39820385e+00 -1.97520927e-01  1.93924034e+00
#    1.82566280e+01  2.36442242e+01  1.95825348e+01  3.00093613e+01
#    3.62571487e+01  3.66538143e+00  1.57079041e+00  1.65844975e+01
#    1.63259239e+01  1.23135738e+01  2.14096928e+01  1.57252560e+01
#    9.46679878e+00 -5.04678965e-01  1.63507664e+00  1.49522705e+01
#    1.21158342e+01  4.42729044e+00]
#  [ 0.00000000e+00 -2.34860396e+00 -3.24503183e-01  1.43979013e+00
#   -1.81348267e+01 -2.84092922e+01 -1.47559938e+01 -1.15534296e+01
#   -2.68487358e+01 -1.19921722e+01 -3.98684740e+00 -1.51064644e+01
#   -1.53982029e+01 -1.76867332e+01 -1.81264877e+01 -2.18222084e+01
#   -6.35827017e+00  2.40807056e+00  7.75084925e+00  2.05871353e+01
#    8.32645798e+00  2.94820070e+00]]

# %%
DTW(1,2,1,mfcc_m1.transpose(),mfcc_f1.transpose(), vect)
# Out:
# 70.12889353434245

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# ### Création des variables de manipluation des fichiers

# %%
actions = ["arretetoi","atterrissage","avance","decollage","droite","etatdurgence","faisunflip","gauche","plusbas","plushaut","recule","tournedroite","tournegauche"]

IDs_M_nonbruite = ['M%.2d'%i for i in range(1, 14)]
IDs_F_nonbruite = ['F%.2d'%i for i in range(1, 6)]

IDs_M_bruite = ['M%.2d'%i for i in range(1, 5)]
IDs_F_bruite = ['F%.2d'%i for i in range(0)] #Pas d'exemple féminin présents

IDs_M_test = ['M%.2d'%i for i in range(1,2)]
IDs_F_test = ['F%.2d'%i for i in range(0)] #Pas d'exemple féminin présents

IDs_M_dgo_test_nb = ['M%.2d'%i for i in range(20,21)]
IDs_M_dgo_test_b = ['M%.2d'%i for i in range(21,22)]
IDs_F_test = ['F%.2d'%i for i in range(0)] #Pas d'exemple féminin présents

IDs_M_reference = ['M%.2d'%i for i in range(1,2)]
IDs_F_reference = ['F%.2d'%i for i in range(0)] #Pas d'exemple féminin présents

IDs_nonbruite = IDs_M_nonbruite + IDs_F_nonbruite
IDs_bruite = IDs_M_bruite + IDs_F_bruite
IDs_test = IDs_M_test + IDs_F_test
IDs_dgonb = IDs_M_dgo_test_nb
IDs_dgob = IDs_M_dgo_test_b
IDs_reference = IDs_M_reference + IDs_F_reference


IDs = {"nonbruite": IDs_nonbruite,
        "bruite": IDs_bruite,
        "test": IDs_test,
        "diegonb": IDs_dgonb,
        "diegob": IDs_dgob,
       "reference" : IDs_reference # M01 en attendant de trouver mieux
      }

# %% [markdown]
# #### Fonction de génération du chemin d'un fichier (Linux)

# %%
def gen_path(typeSon, ID, action):
    chemin = ""
    
    if typeSon == "nonbruite":
        chemin = "corpus/dronevolant_nonbruite"
    elif typeSon == "bruite":
        chemin = "corpus/dronevolant_bruite"
    elif typeSon == "test":
        chemin = "corpus_test"
    elif typeSon == "diegonb":
        chemin = "corpus_dgo/non_bruite"
    elif typeSon == "diegob":
        chemin = "corpus_dgo/bruite"
    elif typeSon == "reference":
        chemin = "corpus_reference"
        
    chemin += f"/{ID}_{action}.wav"
    return chemin

# %% [markdown]
# #### Fonction de génération du chemin d'un fichier aléatoire

# %%
def gen_random_path(typeSon):
    selected_IDs = IDs[typeSon]
    return gen_path(typeSon, selected_IDs[randrange(len(selected_IDs))], actions[randrange(len(actions))])

# %% [markdown]
# ## Plot de chaque commande

# %%
for action in actions[1:2]:
    for i,ID in enumerate(IDs["nonbruite"][:4]):
        y, sr = librosa.load(gen_path("nonbruite", ID, action))
        mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
        n_mfcc=8)
        
        plt.subplot(2,4, (i+1))
        plt.title(f'{ID}_{action}')
        plt.plot(mfcc)
        

for action in actions[1:2]:
    for i,ID in enumerate(IDs["bruite"][:4]):
        y, sr = librosa.load(gen_path("bruite", ID, action))
        
        mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
        n_mfcc=8)
        
        plt.subplot(2,4, 4+i+1)
        plt.title(f'{ID}_{action} br')
        plt.plot(mfcc)

plt.show()

# %% [markdown]
# ### Comparer les différents coefficients du mfcc

# %%
plt.clf()

for action in actions[:1]:
    for i,ID in enumerate(IDs_nonbruite[::3]):
        y, sr = librosa.load(gen_path("nonbruite", ID, action))
        
        mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
        n_mfcc=12)
        
        
        
        plt.subplot(2,len(IDs["nonbruite"])/2, (i+1))
        plt.title(f'{ID}_{action}')
        plt.plot(mfcc.transpose())


plt.show()

# %% [markdown]
# ### Comparaison d'une MFCC donnée avec toutes les autres dans le but de retrouver la commande donnée initialement

# %% [markdown]
# #### Fonction pour la comparaison

# %%
def compare_mfcc(filepath):
    y_son, sr_son = librosa.load(filepath)

    mfcc_son_a_decouvrir = librosa.feature.mfcc(y=y_son, sr=sr_son, hop_length=1024, htk=True,
            n_mfcc=8)

    results = []

    max_details_len = 0

    for typeSon in IDs:
        for ID in IDs[typeSon]:
            for action in actions:
                filename = gen_path(typeSon, ID, action)
                if filename != action_to_find:
                    y, sr = librosa.load(filename)

                    mfcc_test = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
                    n_mfcc=8)

                    action_details = f"{typeSon} {action} ({ID})" 

                    if len(action_details) > max_details_len:
                        max_details_len = len(action_details)

                    results.append((action_details, DTW(1,2,1,mfcc_son_a_decouvrir.transpose(), mfcc_test.transpose(), vect)))


    results.sort(key=lambda k:k[1])

    for i, (action, result) in enumerate(results):
        print(f'{i+1}:\t{action:<{max_details_len}}\t|\t{result}')
    print()

    print(f'La commande donnée est donc probablement {results[0][0].split()[1]}')

# %%
action_to_find = gen_random_path("nonbruite")

print(action_to_find, end="\n\n")

compare_mfcc(action_to_find)
# Out:
# corpus/dronevolant_nonbruite/M10_etatdurgence.wav
#
# 1:	nonbruite avance (M10)      	|	52.27507368723551
# 2:	nonbruite etatdurgence (M12)	|	54.55546988062112
# 3:	nonbruite arretetoi (M10)   	|	55.91633167384583
# 4:	nonbruite droite (M10)      	|	57.16789434042322
# 5:	nonbruite tournedroite (M10)	|	59.358928868936935
# 6:	nonbruite etatdurgence (M05)	|	60.626887386792326
# 7:	nonbruite plusbas (M10)     	|	63.39752460780897
# 8:	nonbruite faisunflip (M08)  	|	64.25470072572881
# 9:	nonbruite recule (M10)      	|	64.6387751897176
# 10:	nonbruite gauche (M10)      	|	65.5894185721156
# 11:	nonbruite etatdurgence (M08)	|	65.82711346944173
# 12:	nonbruite etatdurgence (M01)	|	66.28273142119984
# 13:	reference etatdurgence (M01)	|	66.28273142119984
# 14:	nonbruite tournegauche (M10)	|	66.79719531230437
# 15:	nonbruite decollage (M08)   	|	66.82081325430619
# 16:	nonbruite atterrissage (M12)	|	67.6545203794916
# 17:	nonbruite decollage (M13)   	|	67.70346983089003
# 18:	nonbruite atterrissage (M08)	|	67.94023120834167
# 19:	nonbruite etatdurgence (M04)	|	68.24285276312577
# 20:	test etatdurgence (M01)     	|	68.36217984761278
# 21:	nonbruite decollage (M05)   	|	68.46311509609222
# 22:	nonbruite decollage (M06)   	|	68.66401398783982
# 23:	nonbruite faisunflip (M06)  	|	69.05728847377902
# 24:	nonbruite decollage (M04)   	|	69.40024506705147
# 25:	nonbruite tournedroite (M12)	|	69.4676670262843
# 26:	nonbruite tournegauche (M12)	|	69.48771789462067
# 27:	nonbruite tournegauche (M08)	|	69.6219501756642
# 28:	nonbruite avance (M12)      	|	69.70876341599684
# 29:	nonbruite avance (F03)      	|	70.04512179028858
# 30:	nonbruite avance (M08)      	|	71.08353711688329
# 31:	nonbruite faisunflip (F05)  	|	72.27549176467092
# 32:	nonbruite decollage (M03)   	|	72.28409720200759
# 33:	nonbruite atterrissage (M10)	|	72.3235763182123
# 34:	nonbruite plushaut (M12)    	|	72.48211178026702
# 35:	nonbruite etatdurgence (F01)	|	72.59457803279795
# 36:	nonbruite atterrissage (M03)	|	73.17712889451246
# 37:	nonbruite tournegauche (F05)	|	73.24338206266745
# 38:	nonbruite plushaut (M10)    	|	73.40290903162074
# 39:	nonbruite decollage (M09)   	|	73.74062690734863
# 40:	nonbruite tournegauche (M04)	|	73.81043637426276
# 41:	nonbruite gauche (F01)      	|	73.97316677599068
# 42:	test avance (M01)           	|	74.36590009340098
# 43:	nonbruite avance (M04)      	|	74.54434922162224
# 44:	nonbruite droite (M07)      	|	74.79475567157452
# 45:	nonbruite droite (M08)      	|	74.99577984744555
# 46:	nonbruite droite (M12)      	|	75.04638521170911
# 47:	nonbruite arretetoi (M12)   	|	75.158048531948
# 48:	nonbruite gauche (F05)      	|	75.46415642329625
# 49:	nonbruite avance (M01)      	|	75.46988884390217
# 50:	reference avance (M01)      	|	75.46988884390217
# 51:	nonbruite tournedroite (F05)	|	75.6736149461302
# 52:	nonbruite etatdurgence (M07)	|	75.85002944048713
# 53:	nonbruite faisunflip (M05)  	|	76.02965567452567
# 54:	nonbruite etatdurgence (M11)	|	76.0414306734815
# 55:	nonbruite plusbas (M04)     	|	76.05207006014311
# 56:	nonbruite decollage (M12)   	|	76.06816400800433
# 57:	nonbruite etatdurgence (M02)	|	76.37929961555882
# 58:	nonbruite decollage (F03)   	|	76.5871583451616
# 59:	nonbruite decollage (M01)   	|	76.79623549661518
# 60:	reference decollage (M01)   	|	76.79623549661518
# 61:	nonbruite recule (M05)      	|	76.87538651416176
# 62:	nonbruite gauche (M12)      	|	77.04743693787374
# 63:	nonbruite tournedroite (M09)	|	77.08090398082994
# 64:	nonbruite faisunflip (M07)  	|	77.6332633635577
# 65:	nonbruite plusbas (M12)     	|	77.65739865052073
# 66:	nonbruite faisunflip (M10)  	|	78.53285937560231
# 67:	nonbruite etatdurgence (M09)	|	78.53394102438902
# 68:	nonbruite avance (M13)      	|	78.63362094683525
# 69:	nonbruite recule (M12)      	|	79.28586681072528
# 70:	nonbruite avance (F05)      	|	79.2951669546274
# 71:	nonbruite etatdurgence (F05)	|	79.32774541464197
# 72:	nonbruite avance (M09)      	|	79.45020376352163
# 73:	nonbruite droite (M04)      	|	79.57709086281913
# 74:	nonbruite gauche (M06)      	|	79.5873366345416
# 75:	nonbruite etatdurgence (F03)	|	79.72135465795344
# 76:	nonbruite etatdurgence (M06)	|	79.75785588643637
# 77:	nonbruite faisunflip (M03)  	|	79.99949786242317
# 78:	nonbruite tournedroite (M04)	|	80.0863770785397
# 79:	nonbruite droite (F01)      	|	80.16294144221715
# 80:	nonbruite faisunflip (M12)  	|	80.25669697681106
# 81:	nonbruite atterrissage (M04)	|	80.26241354746361
# 82:	nonbruite arretetoi (M11)   	|	80.30429815634703
# 83:	nonbruite arretetoi (M04)   	|	80.67242099217006
# 84:	nonbruite droite (M03)      	|	80.82621800349308
# 85:	nonbruite droite (M05)      	|	80.96066327776228
# 86:	nonbruite gauche (M08)      	|	80.96938607631586
# 87:	nonbruite avance (M06)      	|	81.10920818721023
# 88:	nonbruite recule (F03)      	|	81.17300024899569
# 89:	nonbruite tournegauche (M05)	|	81.3347924079424
# 90:	nonbruite droite (F05)      	|	81.60133019538775
# 91:	test tournedroite (M01)     	|	81.79632083789723
# 92:	nonbruite decollage (M11)   	|	82.04348256037785
# 93:	nonbruite atterrissage (M06)	|	82.42540544452089
# 94:	nonbruite recule (M08)      	|	82.77657042051617
# 95:	nonbruite plushaut (M05)    	|	82.802917382656
# 96:	nonbruite plusbas (M05)     	|	82.87529349621431
# 97:	nonbruite faisunflip (M04)  	|	82.87739591037526
# 98:	nonbruite atterrissage (M09)	|	83.34879418423301
# 99:	test droite (M01)           	|	83.55560488019671
# 100:	nonbruite tournedroite (M05)	|	83.80250881740025
# 101:	nonbruite faisunflip (M02)  	|	83.85051086621407
# 102:	nonbruite tournedroite (M08)	|	84.0140706614444
# 103:	nonbruite tournedroite (F01)	|	84.05995743362992
# 104:	nonbruite atterrissage (M05)	|	84.18066576302769
# 105:	nonbruite atterrissage (F03)	|	84.42486234144731
# 106:	nonbruite avance (M11)      	|	84.43400192260742
# 107:	nonbruite plushaut (M08)    	|	84.45822348961464
# 108:	nonbruite plushaut (M07)    	|	84.50869680853451
# 109:	nonbruite faisunflip (F02)  	|	84.56749054237649
# 110:	nonbruite gauche (M05)      	|	84.6070882646661
# 111:	nonbruite tournedroite (M01)	|	84.9753367341595
# 112:	reference tournedroite (M01)	|	84.9753367341595
# 113:	diegonb plusbas (M20)       	|	85.02307413274592
# 114:	nonbruite tournedroite (M07)	|	85.17776658194406
# 115:	nonbruite tournedroite (M02)	|	85.2205369501938
# 116:	nonbruite faisunflip (F01)  	|	85.37264318351286
# 117:	nonbruite avance (M05)      	|	85.56915852794909
# 118:	nonbruite arretetoi (M06)   	|	85.77806602729545
# 119:	nonbruite arretetoi (F05)   	|	85.82428469723219
# 120:	nonbruite decollage (F01)   	|	85.984665675041
# 121:	nonbruite decollage (M10)   	|	86.08410164161965
# 122:	nonbruite gauche (F03)      	|	86.1243250803514
# 123:	nonbruite etatdurgence (F02)	|	86.70930368250066
# 124:	nonbruite arretetoi (M05)   	|	86.81824591500418
# 125:	nonbruite droite (M06)      	|	87.09431482671381
# 126:	nonbruite etatdurgence (M03)	|	87.29793130534969
# 127:	nonbruite decollage (M02)   	|	87.30539663214432
# 128:	nonbruite atterrissage (F01)	|	87.55380984715053
# 129:	nonbruite tournegauche (M01)	|	87.83944250036168
# 130:	reference tournegauche (M01)	|	87.83944250036168
# 131:	nonbruite tournedroite (F02)	|	88.14159074582551
# 132:	test atterrissage (M01)     	|	88.14376299146195
# 133:	nonbruite decollage (M07)   	|	88.23357074444111
# 134:	nonbruite gauche (F04)      	|	88.37331295013428
# 135:	nonbruite atterrissage (M13)	|	88.54666180080838
# 136:	nonbruite tournegauche (M02)	|	89.167956976243
# 137:	nonbruite gauche (M04)      	|	89.27062154916617
# 138:	nonbruite decollage (F04)   	|	89.3159251071439
# 139:	nonbruite gauche (M01)      	|	89.34121352747867
# 140:	reference gauche (M01)      	|	89.34121352747867
# 141:	diegonb etatdurgence (M20)  	|	89.34291236080341
# 142:	nonbruite gauche (M03)      	|	89.4897101182204
# 143:	nonbruite faisunflip (M11)  	|	89.61055648021208
# 144:	nonbruite recule (M06)      	|	89.70192677923974
# 145:	nonbruite plushaut (M04)    	|	89.7733893258231
# 146:	nonbruite recule (F05)      	|	89.9250170041437
# 147:	nonbruite recule (M11)      	|	90.00219801852577
# 148:	nonbruite atterrissage (F05)	|	90.11083587228435
# 149:	nonbruite avance (M03)      	|	90.14523491492638
# 150:	nonbruite tournegauche (F01)	|	90.27400106064816
# 151:	nonbruite tournegauche (M06)	|	90.31611583208797
# 152:	nonbruite plushaut (F01)    	|	90.4005049906279
# 153:	nonbruite avance (F01)      	|	90.51173078096829
# 154:	nonbruite atterrissage (M01)	|	90.6248796251085
# 155:	reference atterrissage (M01)	|	90.6248796251085
# 156:	nonbruite faisunflip (M09)  	|	90.63306777118004
# 157:	nonbruite tournegauche (M09)	|	90.63379908970424
# 158:	nonbruite gauche (M07)      	|	90.65299899761493
# 159:	nonbruite plushaut (M09)    	|	90.88408630916051
# 160:	nonbruite plusbas (M08)     	|	91.22484010808608
# 161:	nonbruite faisunflip (M01)  	|	91.29450593171296
# 162:	reference faisunflip (M01)  	|	91.29450593171296
# 163:	nonbruite faisunflip (F04)  	|	91.99808019272824
# 164:	nonbruite plushaut (M11)    	|	92.01710705879407
# 165:	nonbruite tournedroite (F04)	|	92.11942268279661
# 166:	nonbruite arretetoi (M01)   	|	92.4160552777742
# 167:	reference arretetoi (M01)   	|	92.4160552777742
# 168:	test faisunflip (M01)       	|	92.5730230635491
# 169:	nonbruite gauche (M09)      	|	92.80622918265206
# 170:	test decollage (M01)        	|	92.97192672944405
# 171:	nonbruite decollage (F05)   	|	93.03036851149339
# 172:	nonbruite plushaut (M06)    	|	93.19081840129813
# 173:	test plusbas (M01)          	|	93.47699393600713
# 174:	nonbruite plushaut (F05)    	|	93.65941059895052
# 175:	test gauche (M01)           	|	94.07866856671762
# 176:	nonbruite atterrissage (F04)	|	94.19439757953991
# 177:	diegonb tournegauche (M20)  	|	94.21143358403987
# 178:	nonbruite arretetoi (M08)   	|	94.56668635777065
# 179:	nonbruite plusbas (M06)     	|	94.73046024640401
# 180:	nonbruite plusbas (M03)     	|	94.79060827401968
# 181:	nonbruite tournedroite (M06)	|	94.99789219112186
# 182:	nonbruite arretetoi (M09)   	|	95.24788329475804
# 183:	nonbruite arretetoi (F01)   	|	95.5881914345615
# 184:	nonbruite decollage (F02)   	|	95.67245059543185
# 185:	nonbruite etatdurgence (F04)	|	95.88281666148792
# 186:	nonbruite tournegauche (F03)	|	95.95616795799948
# 187:	nonbruite plusbas (M01)     	|	95.96655308859688
# 188:	reference plusbas (M01)     	|	95.96655308859688
# 189:	nonbruite plushaut (M01)    	|	96.08871518648587
# 190:	reference plushaut (M01)    	|	96.08871518648587
# 191:	nonbruite avance (M02)      	|	96.29641449757112
# 192:	diegonb tournedroite (M20)  	|	97.22424282244782
# 193:	diegonb droite (M20)        	|	97.39068944526441
# 194:	nonbruite tournegauche (F04)	|	97.57001938930777
# 195:	nonbruite arretetoi (F02)   	|	97.8327252951013
# 196:	nonbruite tournedroite (M03)	|	97.83943378224092
# 197:	nonbruite gauche (F02)      	|	97.93786958966936
# 198:	nonbruite tournegauche (M03)	|	97.9434131349836
# 199:	nonbruite tournedroite (F03)	|	98.51780310021826
# 200:	nonbruite droite (M09)      	|	98.9177136347844
# 201:	nonbruite droite (M01)      	|	98.99850651989244
# 202:	reference droite (M01)      	|	98.99850651989244
# 203:	nonbruite gauche (M11)      	|	99.21078938075475
# 204:	nonbruite recule (M01)      	|	99.2871746650109
# 205:	reference recule (M01)      	|	99.2871746650109
# 206:	nonbruite droite (F04)      	|	99.38070825028093
# 207:	nonbruite tournedroite (M11)	|	99.3862331531666
# 208:	nonbruite recule (F01)      	|	99.38767609772859
# 209:	nonbruite arretetoi (M07)   	|	99.66398121760442
# 210:	nonbruite recule (M03)      	|	99.7170164841872
# 211:	nonbruite avance (F04)      	|	99.78623381326365
# 212:	nonbruite atterrissage (M02)	|	100.21302121184593
# 213:	nonbruite plusbas (F05)     	|	100.27082011574193
# 214:	nonbruite plushaut (M03)    	|	100.8662504308364
# 215:	nonbruite plusbas (F01)     	|	101.10359400197079
# 216:	nonbruite tournegauche (M11)	|	102.02489824648256
# 217:	test tournegauche (M01)     	|	102.15253955296107
# 218:	nonbruite gauche (M02)      	|	102.21854041604435
# 219:	nonbruite atterrissage (F02)	|	102.41765966170874
# 220:	diegonb avance (M20)        	|	102.53431013858679
# 221:	nonbruite plusbas (M07)     	|	102.57487170879658
# 222:	nonbruite atterrissage (M07)	|	102.84166852510893
# 223:	test arretetoi (M01)        	|	102.90440516685372
# 224:	nonbruite faisunflip (F03)  	|	103.11640366640958
# 225:	nonbruite arretetoi (M02)   	|	103.23985250372635
# 226:	nonbruite plushaut (M02)    	|	103.77858407156808
# 227:	nonbruite droite (M02)      	|	103.80051758710076
# 228:	diegonb decollage (M20)     	|	103.84395868637982
# 229:	nonbruite plusbas (F03)     	|	104.39048606229116
# 230:	nonbruite recule (F02)      	|	104.46222461798253
# 231:	nonbruite plusbas (F02)     	|	104.53520772486557
# 232:	nonbruite recule (M04)      	|	104.60795587812152
# 233:	nonbruite tournegauche (F02)	|	104.7090847061341
# 234:	nonbruite plushaut (F04)    	|	105.5571456677986
# 235:	nonbruite plushaut (F03)    	|	105.60410247614354
# 236:	diegonb gauche (M20)        	|	105.91865267898098
# 237:	nonbruite avance (F02)      	|	105.97106486872623
# 238:	nonbruite plusbas (M09)     	|	106.17861983355354
# 239:	nonbruite atterrissage (M11)	|	106.23395184108189
# 240:	nonbruite arretetoi (F04)   	|	106.55079126358032
# 241:	test plushaut (M01)         	|	106.60686191435784
# 242:	nonbruite plusbas (M11)     	|	106.84165663468211
# 243:	nonbruite recule (M07)      	|	107.28498224111704
# 244:	nonbruite recule (M09)      	|	107.29576307184556
# 245:	nonbruite droite (F03)      	|	107.31083362752742
# 246:	nonbruite arretetoi (F03)   	|	107.4802923636003
# 247:	nonbruite recule (F04)      	|	107.51106621498285
# 248:	nonbruite arretetoi (M03)   	|	107.84716656628777
# 249:	test recule (M01)           	|	108.05189884070194
# 250:	bruite faisunflip (M03)     	|	108.59300062391493
# 251:	bruite etatdurgence (M03)   	|	108.81413958446089
# 252:	bruite plusbas (M01)        	|	109.12373629911447
# 253:	diegonb atterrissage (M20)  	|	109.26052685637973
# 254:	nonbruite plusbas (M02)     	|	109.51726897103445
# 255:	nonbruite plusbas (F04)     	|	109.62827883268658
# 256:	nonbruite avance (M07)      	|	109.93235274094802
# 257:	bruite tournegauche (M03)   	|	110.70512753222363
# 258:	diegonb recule (M20)        	|	112.92545056698927
# 259:	diegonb faisunflip (M20)    	|	113.46123259814817
# 260:	nonbruite gauche (M13)      	|	113.59825232090094
# 261:	bruite arretetoi (M03)      	|	113.87155033991887
# 262:	nonbruite plusbas (M13)     	|	115.1320905440893
# 263:	nonbruite plushaut (M13)    	|	116.43878296094063
# 264:	nonbruite droite (M11)      	|	116.90981483459473
# 265:	bruite atterrissage (M03)   	|	117.9613708229952
# 266:	diegonb plushaut (M20)      	|	118.43120543162028
# 267:	nonbruite recule (M02)      	|	120.4975848858173
# 268:	bruite tournedroite (M03)   	|	120.5142226585975
# 269:	diegonb arretetoi (M20)     	|	120.59722755894516
# 270:	nonbruite droite (F02)      	|	121.48910842222325
# 271:	nonbruite tournegauche (M13)	|	121.54651775130306
# 272:	bruite droite (M03)         	|	121.64491489955357
# 273:	bruite avance (M03)         	|	121.94073936266777
# 274:	bruite decollage (M03)      	|	122.32557338557831
# 275:	nonbruite tournegauche (M07)	|	122.94148386225982
# 276:	bruite decollage (M04)      	|	124.63166702270507
# 277:	bruite plusbas (M03)        	|	124.76742647900994
# 278:	bruite gauche (M03)         	|	124.81914764795548
# 279:	nonbruite droite (M13)      	|	125.02242005177034
# 280:	nonbruite etatdurgence (M13)	|	125.71104803203065
# 281:	bruite recule (M03)         	|	126.02387345142854
# 282:	nonbruite recule (M13)      	|	126.08682286111932
# 283:	nonbruite plushaut (F02)    	|	127.12507408543637
# 284:	bruite plushaut (M03)       	|	128.5321774733694
# 285:	nonbruite tournedroite (M13)	|	129.5300362198441
# 286:	bruite arretetoi (M04)      	|	134.20866734148507
# 287:	bruite faisunflip (M04)     	|	136.2161583957902
# 288:	bruite tournegauche (M04)   	|	136.53084051752666
# 289:	bruite etatdurgence (M04)   	|	136.86980284344065
# 290:	bruite tournedroite (M04)   	|	137.26578967542534
# 291:	nonbruite faisunflip (M13)  	|	137.40074949998123
# 292:	nonbruite arretetoi (M13)   	|	139.46818291513543
# 293:	bruite atterrissage (M04)   	|	142.60137197706433
# 294:	bruite etatdurgence (M02)   	|	143.00563307984234
# 295:	bruite recule (M04)         	|	143.5911887242244
# 296:	bruite atterrissage (M02)   	|	144.44682559260616
# 297:	bruite gauche (M04)         	|	145.32431010196083
# 298:	bruite decollage (M01)      	|	146.1335991282522
# 299:	bruite plushaut (M04)       	|	146.76582892147113
# 300:	bruite plusbas (M04)        	|	147.6167786916097
# 301:	bruite avance (M04)         	|	147.99144079746344
# 302:	bruite recule (M01)         	|	148.42995721415468
# 303:	bruite droite (M04)         	|	148.94489180736053
# 304:	bruite tournegauche (M02)   	|	151.2882271074269
# 305:	bruite faisunflip (M02)     	|	153.285146373592
# 306:	bruite atterrissage (M01)   	|	153.76260626943488
# 307:	diegob tournedroite (M21)   	|	156.56762217051948
# 308:	bruite decollage (M02)      	|	157.152697512978
# 309:	bruite tournedroite (M02)   	|	157.44766959022073
# 310:	diegob etatdurgence (M21)   	|	157.6125162608588
# 311:	bruite faisunflip (M01)     	|	157.88579334356845
# 312:	bruite recule (M02)         	|	159.11181348912856
# 313:	bruite tournegauche (M01)   	|	159.5832318526048
# 314:	diegob decollage (M21)      	|	160.23070728077607
# 315:	diegob arretetoi (M21)      	|	160.32066160259825
# 316:	bruite arretetoi (M02)      	|	160.6215737847721
# 317:	diegob atterrissage (M21)   	|	160.96202799099595
# 318:	bruite tournedroite (M01)   	|	161.50753167234822
# 319:	bruite droite (M02)         	|	161.66830304089714
# 320:	bruite arretetoi (M01)      	|	162.41751108671488
# 321:	diegob tournegauche (M21)   	|	162.6854989600904
# 322:	diegob droite (M21)         	|	163.09716068614614
# 323:	diegob plushaut (M21)       	|	163.206599669023
# 324:	diegob plusbas (M21)        	|	163.33536717511606
# 325:	bruite etatdurgence (M01)   	|	163.3899371807392
# 326:	diegob recule (M21)         	|	163.62071672126427
# 327:	diegob gauche (M21)         	|	163.70201365152994
# 328:	bruite avance (M01)         	|	166.33660185677664
# 329:	bruite plusbas (M02)        	|	166.59054049323586
# 330:	diegob avance (M21)         	|	167.1154655687737
# 331:	bruite gauche (M02)         	|	167.24114098268396
# 332:	bruite plushaut (M01)       	|	168.26389654944924
# 333:	bruite droite (M01)         	|	168.37091891948992
# 334:	diegob faisunflip (M21)     	|	169.13827400776879
# 335:	bruite avance (M02)         	|	180.2289888381958
# 336:	bruite gauche (M01)         	|	184.2580046433669
# 337:	bruite plushaut (M02)       	|	184.46643193562826
#
# La commande donnée est donc probablement avance

# %% [markdown]
# #### Fonction de comparaison montrant la commande la plus probable pour chaque voix

# %%
def compare_mfcc_voices(filepath, affichage = True):
    
    y_son, sr_son = librosa.load(filepath)

    mfcc_son_a_decouvrir = librosa.feature.mfcc(y=y_son, sr=sr_son, hop_length=1024, htk=True,
            n_mfcc=8)

    results = dict()

    max_details_len = 0 
        
    for typeSon in IDs:
        for ID in IDs[typeSon]:
            dtw_min_score = 10**5
            dtw_min_action = ""

            for action in actions:
                filename = gen_path(typeSon, ID, action)
                
                if filename != filepath:
                    y, sr = librosa.load(filename)

                    mfcc_test = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
                    n_mfcc=8)

                    action_details = f"{typeSon} {ID}"
                    action_display = action_details +" "+ action

                    if len(action_display)+1 > max_details_len:
                        max_details_len = len(action_display)

                    dtw_score = DTW(1,2,1,mfcc_son_a_decouvrir.transpose(), mfcc_test.transpose(), vect)

                    if dtw_score < dtw_min_score:
                        dtw_min_score = dtw_score
                        results[action_details] = (action, dtw_min_score)
    
    if affichage:
        for key in sorted(results.keys(), key=lambda k: results[k][1]):
            action, result = results[key]
            action_dsp = f'{key}: {action}'
            print(f'{action_dsp:<{max_details_len}}\t|\t{result}')
            
    return sorted(results.keys(), key=lambda k: results[k][1])

# %%
action_to_find = gen_random_path("nonbruite")

print(action_to_find, end="\n\n")

compare_mfcc_voices(action_to_find)
# Out:
# corpus/dronevolant_nonbruite/M07_faisunflip.wav
#
# nonbruite M12: faisunflip 	|	52.38617131066701
# nonbruite M08: faisunflip 	|	53.27896564147051
# nonbruite M06: faisunflip 	|	54.79443821436922
# nonbruite M01: faisunflip 	|	56.17580629567631
# reference M01: faisunflip 	|	56.17580629567631
# nonbruite M10: arretetoi  	|	60.41147716709825
# nonbruite M03: faisunflip 	|	61.834201415379844
# nonbruite M05: faisunflip 	|	64.10760848999024
# nonbruite F05: faisunflip 	|	65.74400908606393
# test M01: faisunflip      	|	66.49481648814921
# nonbruite M09: faisunflip 	|	68.09929145956939
# nonbruite M13: decollage  	|	68.49018354126902
# nonbruite F03: recule     	|	70.23610171149758
# nonbruite M04: faisunflip 	|	70.91521612803142
# nonbruite F01: faisunflip 	|	71.39701482984755
# nonbruite F04: plushaut   	|	71.79829665075374
# nonbruite F02: faisunflip 	|	73.45139881821929
# nonbruite M02: faisunflip 	|	74.37566625660864
# diegonb M20: plusbas      	|	77.40126041836209
# nonbruite M07: arretetoi  	|	80.21700736151801
# nonbruite M11: faisunflip 	|	82.22251984168743
# bruite M03: avance        	|	97.42373163946743
# bruite M01: plusbas       	|	105.90122598116515
# bruite M04: arretetoi     	|	111.54471164279514
# bruite M02: etatdurgence  	|	125.4323683684727
# diegob M21: decollage     	|	132.23025759061179
# ['nonbruite M12',
#  'nonbruite M08',
#  'nonbruite M06',
#  'nonbruite M01',
#  'reference M01',
#  'nonbruite M10',
#  'nonbruite M03',
#  'nonbruite M05',
#  'nonbruite F05',
#  'test M01',
#  'nonbruite M09',
#  'nonbruite M13',
#  'nonbruite F03',
#  'nonbruite M04',
#  'nonbruite F01',
#  'nonbruite F04',
#  'nonbruite F02',
#  'nonbruite M02',
#  'diegonb M20',
#  'nonbruite M07',
#  'nonbruite M11',
#  'nonbruite M12',
#  'nonbruite M07',
#  'test M01',
#  'diegonb M20',
#  'bruite M03',
#  'bruite M01',
#  'bruite M04',
#  'bruite M02',
#  'diegob M21']

# %% [markdown]
# ### Test avec le corpus de voix perso

# %%
action_to_find = gen_random_path("test")

print(action_to_find, end="\n\n")

compare_mfcc(action_to_find)
# Out:
# corpus_test/M01_droite.wav
#
# 1:	test tournedroite (M01)     	|	55.9722307068961
# 2:	nonbruite droite (M12)      	|	58.05537245008681
# 3:	diegonb plusbas (M20)       	|	59.39041426907415
# 4:	nonbruite plusbas (M12)     	|	62.99788216886849
# 5:	test etatdurgence (M01)     	|	64.82035460038618
# 6:	nonbruite tournedroite (M12)	|	65.06992721557617
# 7:	nonbruite droite (M05)      	|	66.55745249528151
# 8:	nonbruite droite (M07)      	|	67.49823606775162
# 9:	nonbruite tournedroite (M10)	|	68.40741948520436
# 10:	nonbruite recule (F03)      	|	69.43329478672572
# 11:	nonbruite droite (M10)      	|	69.67513615534855
# 12:	nonbruite plushaut (M12)    	|	70.196280002594
# 13:	test gauche (M01)           	|	71.19095652711158
# 14:	nonbruite tournedroite (M07)	|	71.35068849416879
# 15:	nonbruite avance (M13)      	|	71.69672362009685
# 16:	test avance (M01)           	|	71.73299469138091
# 17:	nonbruite avance (M12)      	|	71.75736293792724
# 18:	nonbruite plushaut (M05)    	|	73.35989735921224
# 19:	nonbruite tournegauche (M12)	|	73.59701594184426
# 20:	test decollage (M01)        	|	74.30683416690466
# 21:	diegonb droite (M20)        	|	74.55622231960297
# 22:	nonbruite decollage (M05)   	|	75.28770722734167
# 23:	test plusbas (M01)          	|	75.30187839685485
# 24:	nonbruite arretetoi (M12)   	|	75.59049835205079
# 25:	nonbruite tournedroite (F05)	|	75.61955212679776
# 26:	nonbruite gauche (M10)      	|	75.6681506230281
# 27:	nonbruite droite (M04)      	|	76.13864935361423
# 28:	nonbruite decollage (M13)   	|	76.58306088167079
# 29:	test arretetoi (M01)        	|	76.78302978982731
# 30:	nonbruite gauche (F03)      	|	77.27657688685827
# 31:	nonbruite gauche (M12)      	|	77.45289642091781
# 32:	nonbruite gauche (M06)      	|	77.66032937454851
# 33:	test faisunflip (M01)       	|	77.93225022858265
# 34:	diegonb tournedroite (M20)  	|	78.09723499843052
# 35:	nonbruite tournedroite (M09)	|	78.1090018532493
# 36:	nonbruite plushaut (M10)    	|	78.25718931167845
# 37:	nonbruite plusbas (M10)     	|	78.38394046651906
# 38:	nonbruite etatdurgence (F03)	|	79.11722431182861
# 39:	nonbruite recule (M12)      	|	79.1351853688558
# 40:	nonbruite etatdurgence (M05)	|	79.48775225552646
# 41:	nonbruite plusbas (M04)     	|	79.58281691530918
# 42:	nonbruite droite (M08)      	|	79.86994185014204
# 43:	nonbruite droite (M03)      	|	80.29061215989132
# 44:	nonbruite tournegauche (M08)	|	80.55904575694692
# 45:	nonbruite plushaut (M07)    	|	80.59885822296143
# 46:	nonbruite tournedroite (F03)	|	80.63232392531175
# 47:	nonbruite plusbas (M05)     	|	80.80088678995769
# 48:	nonbruite droite (F05)      	|	80.94260524402965
# 49:	nonbruite avance (M10)      	|	81.07699324592711
# 50:	nonbruite droite (M06)      	|	81.10258327118338
# 51:	nonbruite recule (M05)      	|	81.5737592434061
# 52:	nonbruite tournegauche (F05)	|	82.25995413462321
# 53:	nonbruite tournedroite (M01)	|	82.57673021346804
# 54:	reference tournedroite (M01)	|	82.57673021346804
# 55:	test plushaut (M01)         	|	82.65941845286976
# 56:	nonbruite avance (M01)      	|	82.77088345614347
# 57:	reference avance (M01)      	|	82.77088345614347
# 58:	nonbruite recule (M07)      	|	83.01686382293701
# 59:	diegonb tournegauche (M20)  	|	83.11847786108653
# 60:	nonbruite decollage (M03)   	|	83.16939569026866
# 61:	nonbruite etatdurgence (M12)	|	83.50432721651518
# 62:	nonbruite etatdurgence (M10)	|	83.55560488019671
# 63:	nonbruite gauche (F04)      	|	83.68450730422447
# 64:	nonbruite atterrissage (F03)	|	84.19883213043212
# 65:	nonbruite avance (F03)      	|	84.31569760466274
# 66:	nonbruite gauche (M01)      	|	84.3501278449749
# 67:	reference gauche (M01)      	|	84.3501278449749
# 68:	nonbruite tournegauche (M04)	|	84.61147689819336
# 69:	nonbruite droite (F01)      	|	84.75609823373648
# 70:	nonbruite gauche (F01)      	|	84.83195742093599
# 71:	diegonb decollage (M20)     	|	84.91443248748779
# 72:	nonbruite faisunflip (M06)  	|	85.01135165070835
# 73:	test tournegauche (M01)     	|	85.05937293859628
# 74:	nonbruite faisunflip (M08)  	|	85.36665823800223
# 75:	nonbruite arretetoi (M10)   	|	85.44253588479663
# 76:	nonbruite droite (M09)      	|	85.4717411284751
# 77:	nonbruite decollage (M09)   	|	85.51181235680214
# 78:	nonbruite tournegauche (M10)	|	85.64182812372843
# 79:	nonbruite faisunflip (M12)  	|	85.7798449589656
# 80:	nonbruite plusbas (M01)     	|	85.83850677196796
# 81:	reference plusbas (M01)     	|	85.83850677196796
# 82:	nonbruite gauche (M05)      	|	85.91672857876482
# 83:	nonbruite tournegauche (F03)	|	86.23638185773576
# 84:	nonbruite tournedroite (M08)	|	86.43881436051994
# 85:	nonbruite plusbas (M07)     	|	86.4764904265708
# 86:	nonbruite recule (M10)      	|	86.94918289184571
# 87:	nonbruite plushaut (M01)    	|	87.1619607925415
# 88:	reference plushaut (M01)    	|	87.1619607925415
# 89:	nonbruite etatdurgence (M01)	|	87.40059613424634
# 90:	reference etatdurgence (M01)	|	87.40059613424634
# 91:	nonbruite avance (M05)      	|	87.41024835759943
# 92:	nonbruite decollage (M01)   	|	87.46095947992234
# 93:	reference decollage (M01)   	|	87.46095947992234
# 94:	nonbruite etatdurgence (M09)	|	87.59825833638509
# 95:	nonbruite tournegauche (M01)	|	88.03553124079629
# 96:	reference tournegauche (M01)	|	88.03553124079629
# 97:	nonbruite droite (F03)      	|	88.05565850394113
# 98:	nonbruite tournedroite (M05)	|	88.32337562854474
# 99:	nonbruite atterrissage (M12)	|	88.35263349092924
# 100:	nonbruite decollage (M08)   	|	88.45807766092234
# 101:	nonbruite plusbas (M13)     	|	88.4645123163859
# 102:	nonbruite decollage (M06)   	|	88.4729621793017
# 103:	nonbruite tournedroite (F01)	|	88.6767807006836
# 104:	nonbruite atterrissage (M05)	|	88.75470657348633
# 105:	diegonb etatdurgence (M20)  	|	88.79018207472198
# 106:	nonbruite plushaut (F05)    	|	88.80944182078044
# 107:	nonbruite avance (M09)      	|	88.8584001419392
# 108:	nonbruite gauche (M09)      	|	88.86988713191106
# 109:	nonbruite gauche (M08)      	|	88.98915640513103
# 110:	nonbruite gauche (F05)      	|	89.00284451704759
# 111:	nonbruite decollage (M07)   	|	89.05380938915496
# 112:	nonbruite plushaut (M08)    	|	89.13494714101155
# 113:	test recule (M01)           	|	89.61774730682373
# 114:	nonbruite avance (M06)      	|	89.68424876352374
# 115:	nonbruite gauche (M03)      	|	89.78958836007625
# 116:	nonbruite plushaut (M06)    	|	89.855583238013
# 117:	test atterrissage (M01)     	|	90.09921799065931
# 118:	nonbruite plusbas (M06)     	|	90.21120179005159
# 119:	diegonb recule (M20)        	|	90.3259506225586
# 120:	nonbruite plushaut (M03)    	|	90.43576538085938
# 121:	diegonb gauche (M20)        	|	90.45013717810313
# 122:	nonbruite tournedroite (F02)	|	90.52503197768638
# 123:	nonbruite decollage (M04)   	|	90.52543243995079
# 124:	nonbruite gauche (M07)      	|	91.03802088473705
# 125:	nonbruite tournegauche (M06)	|	91.17654475459346
# 126:	nonbruite plushaut (M09)    	|	91.50896109067477
# 127:	nonbruite plusbas (F03)     	|	91.81460571289062
# 128:	nonbruite faisunflip (M07)  	|	91.86182838439942
# 129:	nonbruite recule (M03)      	|	91.8781043519365
# 130:	nonbruite tournedroite (M02)	|	91.9199568127829
# 131:	nonbruite tournedroite (M04)	|	91.94175435846502
# 132:	diegonb avance (M20)        	|	92.06718333562215
# 133:	nonbruite plusbas (M03)     	|	92.3037809818349
# 134:	nonbruite avance (M04)      	|	92.42314903259278
# 135:	nonbruite tournedroite (F04)	|	92.61492450420673
# 136:	nonbruite plushaut (M13)    	|	92.79992351531982
# 137:	nonbruite faisunflip (F05)  	|	93.04801940917969
# 138:	nonbruite atterrissage (M13)	|	93.05143114120241
# 139:	nonbruite atterrissage (M06)	|	93.06424651911229
# 140:	diegonb plushaut (M20)      	|	93.12395477294922
# 141:	bruite plusbas (M03)        	|	93.18473143804641
# 142:	nonbruite recule (M06)      	|	93.21498509457237
# 143:	nonbruite avance (F05)      	|	93.83195990704476
# 144:	nonbruite tournegauche (M05)	|	93.946225786966
# 145:	nonbruite tournegauche (M09)	|	94.18979652111346
# 146:	nonbruite tournegauche (M03)	|	94.49987389491154
# 147:	nonbruite tournegauche (M02)	|	94.66046457442026
# 148:	bruite atterrissage (M03)   	|	94.79548723557416
# 149:	nonbruite droite (M01)      	|	94.99906650890003
# 150:	reference droite (M01)      	|	94.99906650890003
# 151:	nonbruite faisunflip (M01)  	|	95.18424648708768
# 152:	reference faisunflip (M01)  	|	95.18424648708768
# 153:	nonbruite recule (F05)      	|	95.29031906127929
# 154:	nonbruite plushaut (F04)    	|	95.34685860151126
# 155:	nonbruite tournedroite (M06)	|	95.41855913972202
# 156:	bruite etatdurgence (M03)   	|	95.44574837317833
# 157:	nonbruite atterrissage (M09)	|	95.47945022583008
# 158:	nonbruite faisunflip (F03)  	|	95.48514164515905
# 159:	nonbruite etatdurgence (M08)	|	95.64401791890462
# 160:	nonbruite arretetoi (M01)   	|	95.96312536042312
# 161:	reference arretetoi (M01)   	|	95.96312536042312
# 162:	nonbruite plushaut (F03)    	|	96.15687754797557
# 163:	nonbruite decollage (M12)   	|	96.16971778869629
# 164:	nonbruite faisunflip (M04)  	|	96.34161178588867
# 165:	nonbruite arretetoi (M07)   	|	96.35691249116938
# 166:	nonbruite etatdurgence (F05)	|	96.54081608698918
# 167:	nonbruite recule (M11)      	|	96.5722006436052
# 168:	nonbruite gauche (M13)      	|	96.59501667022705
# 169:	nonbruite arretetoi (M05)   	|	96.60976336552547
# 170:	nonbruite tournegauche (F01)	|	96.61903296018902
# 171:	diegonb arretetoi (M20)     	|	96.700097878774
# 172:	nonbruite plushaut (M04)    	|	96.82402207301213
# 173:	nonbruite etatdurgence (M04)	|	96.95989029982994
# 174:	nonbruite plusbas (M08)     	|	97.50325294494628
# 175:	nonbruite arretetoi (F05)   	|	97.74930988658558
# 176:	nonbruite faisunflip (M02)  	|	97.75070075988769
# 177:	bruite recule (M03)         	|	97.92377198537191
# 178:	nonbruite recule (M01)      	|	98.09821548461915
# 179:	reference recule (M01)      	|	98.09821548461915
# 180:	nonbruite atterrissage (M03)	|	98.11007877106363
# 181:	nonbruite atterrissage (F05)	|	98.13085888949307
# 182:	bruite decollage (M03)      	|	98.19049425992098
# 183:	bruite plushaut (M03)       	|	98.25607082761567
# 184:	nonbruite decollage (M11)   	|	98.29151573181153
# 185:	nonbruite etatdurgence (F04)	|	98.33900849478586
# 186:	nonbruite arretetoi (F03)   	|	98.35293061392647
# 187:	nonbruite arretetoi (M09)   	|	98.39498546205718
# 188:	nonbruite gauche (M04)      	|	98.39992880313955
# 189:	nonbruite etatdurgence (M03)	|	98.43430765325373
# 190:	bruite tournegauche (M03)   	|	98.60760010939379
# 191:	nonbruite avance (M08)      	|	98.7289438035753
# 192:	nonbruite plusbas (F05)     	|	98.90358300044619
# 193:	nonbruite faisunflip (M11)  	|	98.95560824076334
# 194:	nonbruite etatdurgence (M11)	|	99.14048706539093
# 195:	nonbruite faisunflip (M09)  	|	99.20256853970615
# 196:	nonbruite arretetoi (M06)   	|	99.26631373575289
# 197:	nonbruite tournegauche (F04)	|	99.38065512040082
# 198:	nonbruite faisunflip (M05)  	|	99.61922762944148
# 199:	bruite tournedroite (M03)   	|	99.67135925292969
# 200:	nonbruite etatdurgence (M02)	|	99.74494736770103
# 201:	nonbruite plushaut (M11)    	|	99.83629582722982
# 202:	nonbruite tournegauche (M13)	|	99.9474355844351
# 203:	nonbruite recule (M09)      	|	100.05493453979493
# 204:	nonbruite recule (F04)      	|	100.34232756670784
# 205:	nonbruite etatdurgence (M06)	|	100.40770263671875
# 206:	nonbruite etatdurgence (M07)	|	100.51410743713379
# 207:	nonbruite atterrissage (M08)	|	100.55494977510892
# 208:	nonbruite droite (F04)      	|	100.5670057816939
# 209:	nonbruite recule (M08)      	|	100.57336846713362
# 210:	nonbruite avance (F01)      	|	100.7510160446167
# 211:	nonbruite recule (M04)      	|	100.86491790184608
# 212:	nonbruite etatdurgence (F01)	|	100.89750259800961
# 213:	bruite faisunflip (M03)     	|	100.97114018031529
# 214:	nonbruite gauche (M11)      	|	101.08527946472168
# 215:	bruite droite (M03)         	|	101.28855991363525
# 216:	nonbruite faisunflip (M03)  	|	101.45624038696289
# 217:	nonbruite tournedroite (M11)	|	101.47497849237351
# 218:	nonbruite arretetoi (M03)   	|	101.47590927124024
# 219:	nonbruite recule (F01)      	|	101.49318125891307
# 220:	nonbruite plusbas (M09)     	|	101.62390792846679
# 221:	nonbruite decollage (F02)   	|	101.64203916277204
# 222:	nonbruite plushaut (F01)    	|	101.78051744658372
# 223:	bruite arretetoi (M03)      	|	102.01603507995605
# 224:	nonbruite decollage (F03)   	|	102.0254592393574
# 225:	nonbruite atterrissage (M04)	|	102.24621998180042
# 226:	nonbruite tournedroite (M13)	|	102.24918528965541
# 227:	bruite gauche (M03)         	|	102.39275951385498
# 228:	nonbruite faisunflip (F04)  	|	102.61016579678184
# 229:	nonbruite arretetoi (M04)   	|	102.82281831594614
# 230:	nonbruite avance (M03)      	|	103.01981402458028
# 231:	nonbruite tournedroite (M03)	|	103.06333610534668
# 232:	diegonb faisunflip (M20)    	|	103.55191386475855
# 233:	nonbruite tournegauche (M11)	|	103.72798168848432
# 234:	nonbruite recule (M13)      	|	103.92219681575381
# 235:	nonbruite atterrissage (F04)	|	104.02903823852539
# 236:	nonbruite avance (M11)      	|	104.17992935180663
# 237:	nonbruite decollage (F04)   	|	104.82053641813347
# 238:	nonbruite arretetoi (F01)   	|	104.88679345937875
# 239:	nonbruite tournegauche (F02)	|	104.90821175208458
# 240:	nonbruite arretetoi (M08)   	|	105.10631862053505
# 241:	nonbruite etatdurgence (M13)	|	105.23044779944041
# 242:	nonbruite avance (M07)      	|	105.4832203236032
# 243:	nonbruite atterrissage (M01)	|	105.52391766744947
# 244:	reference atterrissage (M01)	|	105.52391766744947
# 245:	nonbruite faisunflip (M10)  	|	105.56615296725569
# 246:	nonbruite decollage (M02)   	|	105.60045123922414
# 247:	nonbruite decollage (M10)   	|	105.6351953536745
# 248:	nonbruite droite (M13)      	|	105.69399032592773
# 249:	nonbruite decollage (F05)   	|	106.12334111531575
# 250:	nonbruite plusbas (F01)     	|	106.17167735921926
# 251:	diegonb atterrissage (M20)  	|	106.43179165587134
# 252:	nonbruite atterrissage (M10)	|	106.73415996844952
# 253:	nonbruite tournegauche (M07)	|	107.07247100830078
# 254:	nonbruite arretetoi (F04)   	|	107.22119216918945
# 255:	nonbruite plushaut (M02)    	|	107.50451704171988
# 256:	nonbruite etatdurgence (F02)	|	107.63557668413435
# 257:	nonbruite faisunflip (F01)  	|	107.79198749248798
# 258:	nonbruite plusbas (F02)     	|	107.87467133052765
# 259:	nonbruite droite (M02)      	|	108.27269424438477
# 260:	nonbruite avance (F04)      	|	108.33565711975098
# 261:	nonbruite arretetoi (M11)   	|	108.97386271158854
# 262:	nonbruite arretetoi (F02)   	|	109.03724822998046
# 263:	nonbruite gauche (M02)      	|	110.44056015014648
# 264:	nonbruite atterrissage (F01)	|	110.53835291405247
# 265:	nonbruite atterrissage (M07)	|	110.55290660452336
# 266:	nonbruite faisunflip (F02)  	|	110.91782155112615
# 267:	nonbruite avance (M02)      	|	110.97365773518881
# 268:	nonbruite decollage (F01)   	|	111.06759630839029
# 269:	nonbruite atterrissage (F02)	|	111.73898099263509
# 270:	nonbruite recule (F02)      	|	112.43388125101725
# 271:	nonbruite avance (F02)      	|	113.3312708098313
# 272:	nonbruite atterrissage (M02)	|	113.41156544404872
# 273:	nonbruite plusbas (M11)     	|	114.82960247171336
# 274:	nonbruite droite (M11)      	|	115.2117349032698
# 275:	nonbruite atterrissage (M11)	|	115.65013122558594
# 276:	nonbruite droite (F02)      	|	116.38280197143554
# 277:	nonbruite gauche (F02)      	|	116.86216207650992
# 278:	nonbruite plushaut (F02)    	|	117.40671591923154
# 279:	nonbruite plusbas (M02)     	|	118.03428547198956
# 280:	nonbruite faisunflip (M13)  	|	118.13119723002116
# 281:	nonbruite plusbas (F04)     	|	118.17038555802971
# 282:	bruite avance (M03)         	|	119.62002360026041
# 283:	nonbruite arretetoi (M02)   	|	120.38350861648033
# 284:	bruite plusbas (M01)        	|	120.52322478521438
# 285:	nonbruite recule (M02)      	|	123.18426091620263
# 286:	diegob tournedroite (M21)   	|	123.87162399291992
# 287:	diegob recule (M21)         	|	124.22748503393056
# 288:	diegob decollage (M21)      	|	125.03968620300293
# 289:	diegob plusbas (M21)        	|	126.60274587893018
# 290:	diegob arretetoi (M21)      	|	127.10163100560506
# 291:	bruite faisunflip (M04)     	|	127.90332494882436
# 292:	diegob plushaut (M21)       	|	128.05029900868735
# 293:	bruite tournegauche (M04)   	|	128.58037138718825
# 294:	diegob droite (M21)         	|	129.5685016711553
# 295:	bruite arretetoi (M04)      	|	129.79602508544923
# 296:	nonbruite arretetoi (M13)   	|	130.58924878876786
# 297:	bruite plushaut (M04)       	|	132.0062042720734
# 298:	bruite tournedroite (M04)   	|	132.6104991032527
# 299:	diegob etatdurgence (M21)   	|	134.77922026965084
# 300:	bruite gauche (M04)         	|	136.14809345376904
# 301:	diegob tournegauche (M21)   	|	136.23557114601135
# 302:	diegob atterrissage (M21)   	|	137.43787609801
# 303:	bruite etatdurgence (M04)   	|	137.57938564845495
# 304:	bruite droite (M04)         	|	137.63897412618002
# 305:	diegob faisunflip (M21)     	|	137.85898605658085
# 306:	bruite plusbas (M04)        	|	137.87371482849122
# 307:	bruite avance (M04)         	|	138.75864550272624
# 308:	bruite recule (M04)         	|	139.63255519866942
# 309:	diegob avance (M21)         	|	141.31279305617014
# 310:	diegob gauche (M21)         	|	141.8398973941803
# 311:	bruite decollage (M01)      	|	141.87960748823863
# 312:	bruite atterrissage (M04)   	|	142.96929223196847
# 313:	bruite decollage (M04)      	|	144.01033444270908
# 314:	bruite etatdurgence (M02)   	|	146.5984014337713
# 315:	bruite recule (M01)         	|	146.84060425593935
# 316:	bruite atterrissage (M02)   	|	148.59296344575426
# 317:	bruite faisunflip (M02)     	|	148.86042924360797
# 318:	bruite tournegauche (M02)   	|	152.1771598815918
# 319:	bruite plusbas (M02)        	|	157.7460245513916
# 320:	bruite droite (M02)         	|	158.39903053283692
# 321:	bruite recule (M02)         	|	159.77004356384276
# 322:	bruite atterrissage (M01)   	|	160.3992575283708
# 323:	bruite faisunflip (M01)     	|	160.6825953801473
# 324:	bruite avance (M01)         	|	161.52963660313532
# 325:	bruite tournedroite (M01)   	|	161.78326742989677
# 326:	bruite tournedroite (M02)   	|	162.09298957824706
# 327:	bruite tournegauche (M01)   	|	162.36683864593505
# 328:	bruite gauche (M02)         	|	164.89847915649415
# 329:	bruite decollage (M02)      	|	165.78754819672685
# 330:	bruite plushaut (M01)       	|	166.38347099304198
# 331:	bruite arretetoi (M02)      	|	166.67949310302734
# 332:	bruite arretetoi (M01)      	|	167.87918478867104
# 333:	bruite droite (M01)         	|	168.9098298093106
# 334:	bruite etatdurgence (M01)   	|	171.7627628962199
# 335:	bruite plushaut (M02)       	|	178.741160413954
# 336:	bruite avance (M02)         	|	181.93061020260765
# 337:	bruite gauche (M01)         	|	182.1842784475773
#
# La commande donnée est donc probablement tournedroite

# %%
import time


action_to_find = gen_random_path("diegob")


print(action_to_find, end="\n\n")

debut=time.time()
results = compare_mfcc_voices(action_to_find, False)
fin= time.time()
print(fin - debut)

print(results)
# Out:
# corpus_dgo/bruite/M21_arretetoi.wav
#
# 20.209232091903687
# ['diegob M21', 'bruite M03', 'bruite M04', 'bruite M02', 'test M01', 'diegonb M20', 'bruite M01', 'nonbruite M07', 'nonbruite M03', 'nonbruite F02', 'nonbruite M12', 'nonbruite M10', 'nonbruite M05', 'nonbruite M08', 'nonbruite M04', 'nonbruite M11', 'nonbruite M09', 'nonbruite F05', 'nonbruite F03', 'nonbruite M01', 'reference M01', 'nonbruite M02', 'nonbruite F01', 'nonbruite M13', 'nonbruite F04', 'nonbruite M06']

# %% [markdown]
# choisir quoi comme base de référence ?

# %%
def compare_mfcc_to_reference(path_action_to_find, references, affichage = True):
    """
    On fixe un ensemble de fichier de référence (M01 par exemple) 
    et on donne a notre fonction une action de test (path_action_to_find).
    Cette fonction retourne les différents score de la DTW entre notre 
    action de test et les actions de notre corpus de référence.    
    
    """
    reference_typeSon, reference_ID = references
    y_son, sr_son = librosa.load(path_action_to_find)
    
    mfcc_son_a_decouvrir = librosa.feature.mfcc(y=y_son, sr=sr_son, hop_length=1024, htk=True,
            n_mfcc=8)

    results = []

    max_details_len = 0 
    dtw_min_score = 10**5
    dtw_min_action = ""
    
    for action in actions:
        filename = gen_path(reference_typeSon, reference_ID, action)
        y, sr = librosa.load(filename)
        mfcc_test = librosa.feature.mfcc(y=y, sr=sr, hop_length=1024, htk=True,
                    n_mfcc=8)
        action_details = f"{reference_typeSon} {reference_ID}"
        action_display = action_details +" "+ action
        dtw_score = DTW(1,2,1,mfcc_son_a_decouvrir.transpose(), mfcc_test.transpose(), vect)
        results.append((action, dtw_score))
    
    return sorted(results, key=lambda x : x[1])

# %%
action_to_find = gen_random_path("diegonb")
print(action_to_find, end="\n\n")

z = compare_mfcc_to_reference(action_to_find, ["reference", "M01"])
df = pd.DataFrame(z, columns =['action de réference', 'score']) 
df
# Out:
# corpus_dgo/non_bruite/M20_atterrissage.wav
#    action de réference       score
# 0         tournegauche   97.322704
# 1            decollage   99.632712
# 2           faisunflip  100.408744
# 3               gauche  101.555848
# 4            arretetoi  103.541911
# 5         etatdurgence  107.999362
# 6         tournedroite  112.617430
# 7              plusbas  112.878200
# 8               recule  113.068003
# 9         atterrissage  113.142106
# 10              avance  113.754641
# 11            plushaut  121.189402
# 12              droite  135.213356

# %%
def get_all_actions_from_path(typeSon):
    """
    Retourne tous les fichiers d'un typeSon (['nonbruite', 'bruite', 'test', 'diegonb', 'diegob'])" 
    """
    selected_IDs = IDs[typeSon]
    return [[gen_path(typeSon, selected_IDs[j], actions[i]) for i in range(len(actions))] for j in range(len(selected_IDs))]

# %%
def all_actions_from_path_withID(typeSon, ID):
    return [gen_path(typeSon, ID, action) for action in actions]

# %%
references_actions = (get_all_actions_from_path("reference"))[0] # dans le cas du corpus référence vu qu'il n'y a qu'un ID (M01 pour l'instant pas besoin de flatten la liste, il suffit de récupérer le premier élément)
for action_de_ref in references_actions:
    print(action_de_ref)
print("\n"*2)
print("--"*20)
print("\n"*2)
flatten = lambda l: [e for m in l for e in m]
references_nonbruite = flatten(get_all_actions_from_path("nonbruite"))
for action_de_nb in references_nonbruite:
    print(action_de_nb)

testdiegonb_actions = get_all_actions_from_path("diegonb")[0]
# Out:
# corpus_reference/M01_arretetoi.wav
# corpus_reference/M01_atterrissage.wav
# corpus_reference/M01_avance.wav
# corpus_reference/M01_decollage.wav
# corpus_reference/M01_droite.wav
# corpus_reference/M01_etatdurgence.wav
# corpus_reference/M01_faisunflip.wav
# corpus_reference/M01_gauche.wav
# corpus_reference/M01_plusbas.wav
# corpus_reference/M01_plushaut.wav
# corpus_reference/M01_recule.wav
# corpus_reference/M01_tournedroite.wav
# corpus_reference/M01_tournegauche.wav
#
#
#
# ----------------------------------------
#
#
#
# corpus/dronevolant_nonbruite/M01_arretetoi.wav
# corpus/dronevolant_nonbruite/M01_atterrissage.wav
# corpus/dronevolant_nonbruite/M01_avance.wav
# corpus/dronevolant_nonbruite/M01_decollage.wav
# corpus/dronevolant_nonbruite/M01_droite.wav
# corpus/dronevolant_nonbruite/M01_etatdurgence.wav
# corpus/dronevolant_nonbruite/M01_faisunflip.wav
# corpus/dronevolant_nonbruite/M01_gauche.wav
# corpus/dronevolant_nonbruite/M01_plusbas.wav
# corpus/dronevolant_nonbruite/M01_plushaut.wav
# corpus/dronevolant_nonbruite/M01_recule.wav
# corpus/dronevolant_nonbruite/M01_tournedroite.wav
# corpus/dronevolant_nonbruite/M01_tournegauche.wav
# corpus/dronevolant_nonbruite/M02_arretetoi.wav
# corpus/dronevolant_nonbruite/M02_atterrissage.wav
# corpus/dronevolant_nonbruite/M02_avance.wav
# corpus/dronevolant_nonbruite/M02_decollage.wav
# corpus/dronevolant_nonbruite/M02_droite.wav
# corpus/dronevolant_nonbruite/M02_etatdurgence.wav
# corpus/dronevolant_nonbruite/M02_faisunflip.wav
# corpus/dronevolant_nonbruite/M02_gauche.wav
# corpus/dronevolant_nonbruite/M02_plusbas.wav
# corpus/dronevolant_nonbruite/M02_plushaut.wav
# corpus/dronevolant_nonbruite/M02_recule.wav
# corpus/dronevolant_nonbruite/M02_tournedroite.wav
# corpus/dronevolant_nonbruite/M02_tournegauche.wav
# corpus/dronevolant_nonbruite/M03_arretetoi.wav
# corpus/dronevolant_nonbruite/M03_atterrissage.wav
# corpus/dronevolant_nonbruite/M03_avance.wav
# corpus/dronevolant_nonbruite/M03_decollage.wav
# corpus/dronevolant_nonbruite/M03_droite.wav
# corpus/dronevolant_nonbruite/M03_etatdurgence.wav
# corpus/dronevolant_nonbruite/M03_faisunflip.wav
# corpus/dronevolant_nonbruite/M03_gauche.wav
# corpus/dronevolant_nonbruite/M03_plusbas.wav
# corpus/dronevolant_nonbruite/M03_plushaut.wav
# corpus/dronevolant_nonbruite/M03_recule.wav
# corpus/dronevolant_nonbruite/M03_tournedroite.wav
# corpus/dronevolant_nonbruite/M03_tournegauche.wav
# corpus/dronevolant_nonbruite/M04_arretetoi.wav
# corpus/dronevolant_nonbruite/M04_atterrissage.wav
# corpus/dronevolant_nonbruite/M04_avance.wav
# corpus/dronevolant_nonbruite/M04_decollage.wav
# corpus/dronevolant_nonbruite/M04_droite.wav
# corpus/dronevolant_nonbruite/M04_etatdurgence.wav
# corpus/dronevolant_nonbruite/M04_faisunflip.wav
# corpus/dronevolant_nonbruite/M04_gauche.wav
# corpus/dronevolant_nonbruite/M04_plusbas.wav
# corpus/dronevolant_nonbruite/M04_plushaut.wav
# corpus/dronevolant_nonbruite/M04_recule.wav
# corpus/dronevolant_nonbruite/M04_tournedroite.wav
# corpus/dronevolant_nonbruite/M04_tournegauche.wav
# corpus/dronevolant_nonbruite/M05_arretetoi.wav
# corpus/dronevolant_nonbruite/M05_atterrissage.wav
# corpus/dronevolant_nonbruite/M05_avance.wav
# corpus/dronevolant_nonbruite/M05_decollage.wav
# corpus/dronevolant_nonbruite/M05_droite.wav
# corpus/dronevolant_nonbruite/M05_etatdurgence.wav
# corpus/dronevolant_nonbruite/M05_faisunflip.wav
# corpus/dronevolant_nonbruite/M05_gauche.wav
# corpus/dronevolant_nonbruite/M05_plusbas.wav
# corpus/dronevolant_nonbruite/M05_plushaut.wav
# corpus/dronevolant_nonbruite/M05_recule.wav
# corpus/dronevolant_nonbruite/M05_tournedroite.wav
# corpus/dronevolant_nonbruite/M05_tournegauche.wav
# corpus/dronevolant_nonbruite/M06_arretetoi.wav
# corpus/dronevolant_nonbruite/M06_atterrissage.wav
# corpus/dronevolant_nonbruite/M06_avance.wav
# corpus/dronevolant_nonbruite/M06_decollage.wav
# corpus/dronevolant_nonbruite/M06_droite.wav
# corpus/dronevolant_nonbruite/M06_etatdurgence.wav
# corpus/dronevolant_nonbruite/M06_faisunflip.wav
# corpus/dronevolant_nonbruite/M06_gauche.wav
# corpus/dronevolant_nonbruite/M06_plusbas.wav
# corpus/dronevolant_nonbruite/M06_plushaut.wav
# corpus/dronevolant_nonbruite/M06_recule.wav
# corpus/dronevolant_nonbruite/M06_tournedroite.wav
# corpus/dronevolant_nonbruite/M06_tournegauche.wav
# corpus/dronevolant_nonbruite/M07_arretetoi.wav
# corpus/dronevolant_nonbruite/M07_atterrissage.wav
# corpus/dronevolant_nonbruite/M07_avance.wav
# corpus/dronevolant_nonbruite/M07_decollage.wav
# corpus/dronevolant_nonbruite/M07_droite.wav
# corpus/dronevolant_nonbruite/M07_etatdurgence.wav
# corpus/dronevolant_nonbruite/M07_faisunflip.wav
# corpus/dronevolant_nonbruite/M07_gauche.wav
# corpus/dronevolant_nonbruite/M07_plusbas.wav
# corpus/dronevolant_nonbruite/M07_plushaut.wav
# corpus/dronevolant_nonbruite/M07_recule.wav
# corpus/dronevolant_nonbruite/M07_tournedroite.wav
# corpus/dronevolant_nonbruite/M07_tournegauche.wav
# corpus/dronevolant_nonbruite/M08_arretetoi.wav
# corpus/dronevolant_nonbruite/M08_atterrissage.wav
# corpus/dronevolant_nonbruite/M08_avance.wav
# corpus/dronevolant_nonbruite/M08_decollage.wav
# corpus/dronevolant_nonbruite/M08_droite.wav
# corpus/dronevolant_nonbruite/M08_etatdurgence.wav
# corpus/dronevolant_nonbruite/M08_faisunflip.wav
# corpus/dronevolant_nonbruite/M08_gauche.wav
# corpus/dronevolant_nonbruite/M08_plusbas.wav
# corpus/dronevolant_nonbruite/M08_plushaut.wav
# corpus/dronevolant_nonbruite/M08_recule.wav
# corpus/dronevolant_nonbruite/M08_tournedroite.wav
# corpus/dronevolant_nonbruite/M08_tournegauche.wav
# corpus/dronevolant_nonbruite/M09_arretetoi.wav
# corpus/dronevolant_nonbruite/M09_atterrissage.wav
# corpus/dronevolant_nonbruite/M09_avance.wav
# corpus/dronevolant_nonbruite/M09_decollage.wav
# corpus/dronevolant_nonbruite/M09_droite.wav
# corpus/dronevolant_nonbruite/M09_etatdurgence.wav
# corpus/dronevolant_nonbruite/M09_faisunflip.wav
# corpus/dronevolant_nonbruite/M09_gauche.wav
# corpus/dronevolant_nonbruite/M09_plusbas.wav
# corpus/dronevolant_nonbruite/M09_plushaut.wav
# corpus/dronevolant_nonbruite/M09_recule.wav
# corpus/dronevolant_nonbruite/M09_tournedroite.wav
# corpus/dronevolant_nonbruite/M09_tournegauche.wav
# corpus/dronevolant_nonbruite/M10_arretetoi.wav
# corpus/dronevolant_nonbruite/M10_atterrissage.wav
# corpus/dronevolant_nonbruite/M10_avance.wav
# corpus/dronevolant_nonbruite/M10_decollage.wav
# corpus/dronevolant_nonbruite/M10_droite.wav
# corpus/dronevolant_nonbruite/M10_etatdurgence.wav
# corpus/dronevolant_nonbruite/M10_faisunflip.wav
# corpus/dronevolant_nonbruite/M10_gauche.wav
# corpus/dronevolant_nonbruite/M10_plusbas.wav
# corpus/dronevolant_nonbruite/M10_plushaut.wav
# corpus/dronevolant_nonbruite/M10_recule.wav
# corpus/dronevolant_nonbruite/M10_tournedroite.wav
# corpus/dronevolant_nonbruite/M10_tournegauche.wav
# corpus/dronevolant_nonbruite/M11_arretetoi.wav
# corpus/dronevolant_nonbruite/M11_atterrissage.wav
# corpus/dronevolant_nonbruite/M11_avance.wav
# corpus/dronevolant_nonbruite/M11_decollage.wav
# corpus/dronevolant_nonbruite/M11_droite.wav
# corpus/dronevolant_nonbruite/M11_etatdurgence.wav
# corpus/dronevolant_nonbruite/M11_faisunflip.wav
# corpus/dronevolant_nonbruite/M11_gauche.wav
# corpus/dronevolant_nonbruite/M11_plusbas.wav
# corpus/dronevolant_nonbruite/M11_plushaut.wav
# corpus/dronevolant_nonbruite/M11_recule.wav
# corpus/dronevolant_nonbruite/M11_tournedroite.wav
# corpus/dronevolant_nonbruite/M11_tournegauche.wav
# corpus/dronevolant_nonbruite/M12_arretetoi.wav
# corpus/dronevolant_nonbruite/M12_atterrissage.wav
# corpus/dronevolant_nonbruite/M12_avance.wav
# corpus/dronevolant_nonbruite/M12_decollage.wav
# corpus/dronevolant_nonbruite/M12_droite.wav
# corpus/dronevolant_nonbruite/M12_etatdurgence.wav
# corpus/dronevolant_nonbruite/M12_faisunflip.wav
# corpus/dronevolant_nonbruite/M12_gauche.wav
# corpus/dronevolant_nonbruite/M12_plusbas.wav
# corpus/dronevolant_nonbruite/M12_plushaut.wav
# corpus/dronevolant_nonbruite/M12_recule.wav
# corpus/dronevolant_nonbruite/M12_tournedroite.wav
# corpus/dronevolant_nonbruite/M12_tournegauche.wav
# corpus/dronevolant_nonbruite/M13_arretetoi.wav
# corpus/dronevolant_nonbruite/M13_atterrissage.wav
# corpus/dronevolant_nonbruite/M13_avance.wav
# corpus/dronevolant_nonbruite/M13_decollage.wav
# corpus/dronevolant_nonbruite/M13_droite.wav
# corpus/dronevolant_nonbruite/M13_etatdurgence.wav
# corpus/dronevolant_nonbruite/M13_faisunflip.wav
# corpus/dronevolant_nonbruite/M13_gauche.wav
# corpus/dronevolant_nonbruite/M13_plusbas.wav
# corpus/dronevolant_nonbruite/M13_plushaut.wav
# corpus/dronevolant_nonbruite/M13_recule.wav
# corpus/dronevolant_nonbruite/M13_tournedroite.wav
# corpus/dronevolant_nonbruite/M13_tournegauche.wav
# corpus/dronevolant_nonbruite/F01_arretetoi.wav
# corpus/dronevolant_nonbruite/F01_atterrissage.wav
# corpus/dronevolant_nonbruite/F01_avance.wav
# corpus/dronevolant_nonbruite/F01_decollage.wav
# corpus/dronevolant_nonbruite/F01_droite.wav
# corpus/dronevolant_nonbruite/F01_etatdurgence.wav
# corpus/dronevolant_nonbruite/F01_faisunflip.wav
# corpus/dronevolant_nonbruite/F01_gauche.wav
# corpus/dronevolant_nonbruite/F01_plusbas.wav
# corpus/dronevolant_nonbruite/F01_plushaut.wav
# corpus/dronevolant_nonbruite/F01_recule.wav
# corpus/dronevolant_nonbruite/F01_tournedroite.wav
# corpus/dronevolant_nonbruite/F01_tournegauche.wav
# corpus/dronevolant_nonbruite/F02_arretetoi.wav
# corpus/dronevolant_nonbruite/F02_atterrissage.wav
# corpus/dronevolant_nonbruite/F02_avance.wav
# corpus/dronevolant_nonbruite/F02_decollage.wav
# corpus/dronevolant_nonbruite/F02_droite.wav
# corpus/dronevolant_nonbruite/F02_etatdurgence.wav
# corpus/dronevolant_nonbruite/F02_faisunflip.wav
# corpus/dronevolant_nonbruite/F02_gauche.wav
# corpus/dronevolant_nonbruite/F02_plusbas.wav
# corpus/dronevolant_nonbruite/F02_plushaut.wav
# corpus/dronevolant_nonbruite/F02_recule.wav
# corpus/dronevolant_nonbruite/F02_tournedroite.wav
# corpus/dronevolant_nonbruite/F02_tournegauche.wav
# corpus/dronevolant_nonbruite/F03_arretetoi.wav
# corpus/dronevolant_nonbruite/F03_atterrissage.wav
# corpus/dronevolant_nonbruite/F03_avance.wav
# corpus/dronevolant_nonbruite/F03_decollage.wav
# corpus/dronevolant_nonbruite/F03_droite.wav
# corpus/dronevolant_nonbruite/F03_etatdurgence.wav
# corpus/dronevolant_nonbruite/F03_faisunflip.wav
# corpus/dronevolant_nonbruite/F03_gauche.wav
# corpus/dronevolant_nonbruite/F03_plusbas.wav
# corpus/dronevolant_nonbruite/F03_plushaut.wav
# corpus/dronevolant_nonbruite/F03_recule.wav
# corpus/dronevolant_nonbruite/F03_tournedroite.wav
# corpus/dronevolant_nonbruite/F03_tournegauche.wav
# corpus/dronevolant_nonbruite/F04_arretetoi.wav
# corpus/dronevolant_nonbruite/F04_atterrissage.wav
# corpus/dronevolant_nonbruite/F04_avance.wav
# corpus/dronevolant_nonbruite/F04_decollage.wav
# corpus/dronevolant_nonbruite/F04_droite.wav
# corpus/dronevolant_nonbruite/F04_etatdurgence.wav
# corpus/dronevolant_nonbruite/F04_faisunflip.wav
# corpus/dronevolant_nonbruite/F04_gauche.wav
# corpus/dronevolant_nonbruite/F04_plusbas.wav
# corpus/dronevolant_nonbruite/F04_plushaut.wav
# corpus/dronevolant_nonbruite/F04_recule.wav
# corpus/dronevolant_nonbruite/F04_tournedroite.wav
# corpus/dronevolant_nonbruite/F04_tournegauche.wav
# corpus/dronevolant_nonbruite/F05_arretetoi.wav
# corpus/dronevolant_nonbruite/F05_atterrissage.wav
# corpus/dronevolant_nonbruite/F05_avance.wav
# corpus/dronevolant_nonbruite/F05_decollage.wav
# corpus/dronevolant_nonbruite/F05_droite.wav
# corpus/dronevolant_nonbruite/F05_etatdurgence.wav
# corpus/dronevolant_nonbruite/F05_faisunflip.wav
# corpus/dronevolant_nonbruite/F05_gauche.wav
# corpus/dronevolant_nonbruite/F05_plusbas.wav
# corpus/dronevolant_nonbruite/F05_plushaut.wav
# corpus/dronevolant_nonbruite/F05_recule.wav
# corpus/dronevolant_nonbruite/F05_tournedroite.wav
# corpus/dronevolant_nonbruite/F05_tournegauche.wav

# %%
def buildConfusionMatrix(corpus_reference = "nonbruite", corpus_test = "test", IDs_test = "M01", affichage = False):
    
    cptbonnesrep = 0
    predictions = [] 
    vraisresultats = actions
#     corpusdetest = get_all_actions_from_path(corpus_test)[int(IDs_test[1:]) - 1]
    corpusdetest = all_actions_from_path_withID(corpus_test, IDs_test)
    print("debut de la construction de la matrice de confusion ... \n |",end =" ")
    n = len(corpusdetest)
    for i in range(n):
        action_a_tester = corpusdetest[i]
        print(f"{i} / {n}", end=" | ")
        z = compare_mfcc_to_reference(action_a_tester, [corpus_reference, "M01"])[0]
        predictions.append(z[0])
        if z[0] == actions[i]:
            cptbonnesrep+=1
    print("fin de la construction.")
    
    if affichage:
        for j in range(n):
            print(actions[j], predictions[j])

    print(f"Sur {len(actions)} actions testés, on a obtenu {cptbonnesrep} bonnes réponses. \n SCORE = {round(cptbonnesrep / len(actions),2)}%")
    return confusion_matrix(actions, predictions)

def drawConfusionMatrix(confusion_matrix):
    df_cm = pd.DataFrame(confusion_matrix, index = [i for i in actions],
                      columns = [i for i in actions])
    plt.figure(figsize=(7,7))
    sn.heatmap(df_cm, annot=True)

# %% [markdown]
# Matrice de confusion :

# %%
cfsm = buildConfusionMatrix("nonbruite", "test") # corpus de réference : "nonbruit", corpus de test : "test"
# Out:
# debut de la construction de la matrice de confusion ...
#  | 0 / 13 | 1 / 13 | 2 / 13 | 3 / 13 | 4 / 13 | 5 / 13 | 6 / 13 | 7 / 13 | 8 / 13 | 9 / 13 | 10 / 13 | 11 / 13 | 12 / 13 | fin de la construction.
# Sur 13 actions testés, on a obtenu 5 bonnes réponses.
#  SCORE = 0.38%

# %%
drawConfusionMatrix(cfsm)

# %%
z = buildConfusionMatrix("reference", "reference")
drawConfusionMatrix(z)
# Out:
# debut de la construction de la matrice de confusion ...
#  | 0 / 13 | 1 / 13 | 2 / 13 | 3 / 13 | 4 / 13 | 5 / 13 | 6 / 13 | 7 / 13 |

# %%
cfsm = buildConfusionMatrix("reference", "nonbruite", "M02")
drawConfusionMatrix(cfsm)
# Out:
# debut de la construction de la matrice de confusion ...
#  | 0 / 13 | 1 / 13 | 2 / 13 | 3 / 13 | 4 / 13 | 5 / 13 | 6 / 13 | 7 / 13 | 8 / 13 | 9 / 13 | 10 / 13 | 11 / 13 | 12 / 13 | fin de la construction.
# Sur 13 actions testés, on a obtenu 10 bonnes réponses.
#  SCORE = 0.77%

# %% [markdown]
# Comparaison M01 sans bruit avec F01 sans bruit

# %%
cfsm = buildConfusionMatrix("reference", "nonbruite", "F01")
drawConfusionMatrix(cfsm)
# Out:
# debut de la construction de la matrice de confusion ...
#  | 0 / 13 | 1 / 13 | 2 / 13 | 3 / 13 | 4 / 13 | 5 / 13 | 6 / 13 | 7 / 13 | 8 / 13 | 9 / 13 | 10 / 13 | 11 / 13 | 12 / 13 | fin de la construction.
# Sur 13 actions testés, on a obtenu 8 bonnes réponses.
#  SCORE = 0.62%

# %% [markdown]
# Partie III, ACP

# %% [markdown]
# Réduction de dimension par $ACP$

# %%
def moyenneMfccs(corpusReference):
    """
    Cette fonction créer la matrice qui contient pour la colonne i, un vecteur de dimension 12 qui correspond à la moyenne colonne par colonne de la mfcc associée
    Input : Liste des 13 actions (.wav), ce corpus représente notre base de référence (définie arbitrairement)
    Output : Matrice numpy (12,13)
    """
    L = []
    for e in corpusReference:
        m1, sr_m1 = librosa.load(e)
        mfcc_m1 = librosa.feature.mfcc(y=m1, sr=sr_m1, hop_length=1024, htk=True,
        n_mfcc=12)
        L.append(np.mean(mfcc_m1.transpose(), axis = 0))
    return np.asarray(L)
 
# on récupère la matrice qui pour la ligne i, contient le vecteur de dimension 12 qui est la moyenne colonne par colonne de l'action i.
I = moyenneMfccs(all_actions_from_path_withID("nonbruite", "M01")).transpose()
scaler = StandardScaler()
scaler.fit(I)
I_center = scaler.transform(I) # on centre les données
pca = PCA(n_components=3)
P = pca.fit_transform(I_center).transpose() # réduction en dimension 3
print(P.shape)

# %%
def build_set_for_suppervisedlearning(typeSon):
    trainingSet = []
    all_ids = IDs[typeSon]
    
    for i in range(len(all_ids)):
        temp = moyenneMfccs(all_actions_from_path_withID(typeSon, all_ids[i])).transpose()
        trainingSet.extend((P @ temp).transpose())
    
    return np.array(trainingSet)

def build_training_set_answers(typeSon):
        
        #Construction des réponses (apprentissage supervisé)
        suppervised = []
        for ID in IDs[typeSon]:
            suppervised.extend(all_actions_from_path_withID(typeSon, ID))
        return suppervised


    
    
    
# # #Construction data set de training
# K = []

# typeSon = "nonbruite"
# all_ids = IDs[typeSon]

# print(all_ids)

# for e in range(len(all_ids)):
#     temp = moyenneMfccs(all_actions_from_path_withID(typeSon, all_ids[e])).transpose()
#     K.extend((P @ temp).transpose())

# #Construction des réponses (apprentissage supervisé)
# suppervised = []
# for ID in IDs[typeSon]:
#     suppervised.extend(all_actions_from_path_withID(typeSon, ID))

# len(suppervised)

# %%
# #Construction data set de test
# K_test = []

# typeSon_test = "reference"
# all_ids = IDs[typeSon_test]

# print(all_ids)

# for e in range(len(all_ids)):
#     temp = moyenneMfccs(all_actions_from_path_withID(typeSon_test, all_ids[e])).transpose()
#     K_test.extend((P @ temp).transpose())

# K_test = np.array(K_test)

# print(K_test.shape)
# print(K_test)

# %%
# remarque : si on utilise nonbruité pour l'apprentissage et référence (qui est un sous ensemble de nonbruité) 
# pour le test, bonne nouvelle on obtient 13 / 13. Par contre si on prend autre chose pour le test les résultats
# sont (assez) mauvais.
def kppv(training_set, suppervied_answers, prediction_set):
    neigh = KNeighborsClassifier(n_neighbors=1)
    neigh.fit(training_set, suppervied_answers) 
    L, R = [], []
    res = neigh.predict(prediction_set)
    cpt = 0
    for pred_i, res_i in list(zip(res, actions)):
        left, right = pred_i.split('/')[-1].split('.')[0].split('_')[-1], res_i 
        L.append(left)
        R.append(right)
        if left == right:
            cpt+=1
    return list(zip(R, L)), cpt

# %%
training_set, suppervied_answers = build_set_for_suppervisedlearning("nonbruite"), build_training_set_answers("nonbruite")
prediction_set = build_set_for_suppervisedlearning("test")
print(training_set.shape, " == ", len(suppervied_answers))
# Out:
# (234, 3)  ==  234

# %%
D, cpt = kppv(training_set, suppervied_answers, prediction_set)
print("score final : ", cpt, " / 13")
df = pd.DataFrame(D, columns=["Actions", "Prédictions"])
df.style.apply(lambda x: ["background: yellow" if x.iloc[1] == x.iloc[0] else "" for v in x], axis = 1)
# Out:
# score final :  3  / 13
# <style  type="text/css" >
#     #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow6_col0 {
#             background:  yellow;
#         }    #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow6_col1 {
#             background:  yellow;
#         }    #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow7_col0 {
#             background:  yellow;
#         }    #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow7_col1 {
#             background:  yellow;
#         }    #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow12_col0 {
#             background:  yellow;
#         }    #T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow12_col1 {
#             background:  yellow;
#         }</style>
# <table id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03b" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Actions</th>
#         <th class="col_heading level0 col1" >Prédictions</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow0_col0" class="data row0 col0" >arretetoi</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow0_col1" class="data row0 col1" >gauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow1_col0" class="data row1 col0" >atterrissage</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow1_col1" class="data row1 col1" >etatdurgence</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow2_col0" class="data row2 col0" >avance</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow2_col1" class="data row2 col1" >decollage</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow3_col0" class="data row3 col0" >decollage</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow3_col1" class="data row3 col1" >atterrissage</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow4_col0" class="data row4 col0" >droite</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow4_col1" class="data row4 col1" >tournegauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow5_col0" class="data row5 col0" >etatdurgence</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow5_col1" class="data row5 col1" >tournegauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow6_col0" class="data row6 col0" >faisunflip</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow6_col1" class="data row6 col1" >faisunflip</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow7_col0" class="data row7 col0" >gauche</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow7_col1" class="data row7 col1" >gauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow8_col0" class="data row8 col0" >plusbas</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow8_col1" class="data row8 col1" >tournegauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow9_col0" class="data row9 col0" >plushaut</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow9_col1" class="data row9 col1" >tournegauche</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow10_col0" class="data row10 col0" >recule</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow10_col1" class="data row10 col1" >arretetoi</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow11_col0" class="data row11 col0" >tournedroite</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow11_col1" class="data row11 col1" >atterrissage</td>
#     </tr>    <tr>
#         <th id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03blevel0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow12_col0" class="data row12 col0" >tournegauche</td>
#         <td id="T_3c29c5a8_02aa_11ea_a6c9_1831bfb1b03brow12_col1" class="data row12 col1" >tournegauche</td>
#     </tr></tbody>
# </table>

# %%
def plot_training_data3D(training_set):
    colors = ["black","slategrey","blue","lightblue","cyan","Green","lightgreen","yellow","brown","orange","red","purple","pink"]
    n = len(actions)
    data_to_plot = [training_set[i::n] for i in range(n)]

    fig = plt.figure()
    nlines, nrows = 7, 2

    fig = plt.figure(figsize=(20,50))

    for i in range(n):
        j = fig.add_subplot(nlines, nrows,i + 1, projection="3d")
        j.set_xlabel('X Label')
        j.set_ylabel('Y Label')
        j.set_zlabel('Z Label')
        j.set_ylim([-40,30])
        j.set_xlim([-7000,-4000])
        j.set_zlim([-8,4])

        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        j.scatter(x, y, z, c=colors[i], label=actions[i], s = 100, edgecolors='black')
        j.set_title("Données d'apprentissage pour : " + actions[i])
        j.legend(loc='center left', prop={'size': 15})
    plt.show()

# %%
plot_training_data3D(training_set)

# %%
def plot_training_and_prediction_data3D(training_set, prediction_set, size_dots_training_set, size_dots_prediction_set):
    
    n = len(actions)
    data_to_plot = [training_set[i::n] for i in range(n)]
    colors = ["black","slategrey","blue","lightblue","cyan","Green","lightgreen","yellow","brown","orange","red","purple","pink"]
    
    fig = plt.figure(constrained_layout=True)
    gs = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)
    fig = plt.figure(figsize=(20,40))
    
    #### Plot training data + prediction data ####
    
    ax = fig.add_subplot(gs[0, :], projection="3d")
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')

    for i in range(n):
        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        ax.scatter(x,y,z, c=colors[i], s=size_dots_training_set, alpha=0.20, edgecolors="black")

    xpredict, ypredict, zpredict = prediction_set[:,0], prediction_set[:,1], prediction_set[:,2]
    for i in range(n):
        ax.scatter(xpredict[i], ypredict[i], zpredict[i], c=colors[i], label=actions[i], s=size_dots_prediction_set, edgecolors="black")

    ax.legend(loc='center left', prop={'size': 15})    
    ax.set_title("Données d'apprentissage ET données de tests")

    
    
    
    
    #### Plot training data ####

    fig = plt.figure(figsize=(20,20))
    ax2 = fig.add_subplot(gs[1,0], projection="3d")
    ax2.set_xlabel('X Label')
    ax2.set_ylabel('Y Label')
    ax2.set_zlabel('Z Label')
    ax2.set_title("Données d'apprentissage")


    for i in range(n):
        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        ax2.scatter(x,y,z, c=colors[i], label=actions[i], s=size_dots_training_set, alpha=0.20, edgecolors="black")
        ax2.legend(loc='center left', prop={'size': 15})


    
    
    #### prediction data ####

    ax3 = fig.add_subplot(gs[1,1], projection="3d")
    ax3.set_xlabel('X Label')
    ax3.set_ylabel('Y Label')
    ax3.set_zlabel('Z Label')
    ax3.set_title("Données de tests")

    for i in range(13):
        ax3.scatter(xpredict[i], ypredict[i], zpredict[i], c=colors[i], label=actions[i], s=size_dots_prediction_set, edgecolors="black")

    ax3.legend(loc='center left', prop={'size': 15})    

    plt.show()

# %%
plot_training_and_prediction_data3D(training_set, prediction_set, 70, 140)

# %%
training_set, suppervied_answers = build_set_for_suppervisedlearning("nonbruite"), build_training_set_answers("nonbruite")
prediction_set = build_set_for_suppervisedlearning("test")
print(training_set.shape, " == ", len(suppervied_answers))

# %%
D, cpt = kppv(training_set, suppervied_answers, prediction_set)
print("score final : ", cpt, " / 13")
df = pd.DataFrame(D, columns=["Actions", "Prédictions"])
df.style.apply(lambda x: ["background: yellow" if x.iloc[1] == x.iloc[0] else "" for v in x], axis = 1)

# %%
def plot_training_data3D(training_set):
    n = len(actions)
    data_to_plot = [training_set[i::n] for i in range(n)]

    fig = plt.figure()
    nlines, nrows = 7, 2

    fig = plt.figure(figsize=(20,50))

    for i in range(n):
        j = fig.add_subplot(nlines, nrows,i + 1, projection="3d")
        j.set_xlabel('X Label')
        j.set_ylabel('Y Label')
        j.set_zlabel('Z Label')
        j.set_ylim([-40,30])
        j.set_xlim([-7000,-4000])
        j.set_zlim([-8,4])

        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        j.scatter(x, y, z, c=colors[i], label=actions[i], s = 100, edgecolors='black')
        j.set_title("Données d'apprentissage pour : " + actions[i])
        j.legend(loc='center left', prop={'size': 15})
    plt.show()

# %%
plot_training_data3D(training_set)

# %%
def plot_training_and_prediction_data3D(training_set, prediction_set, size_dots_training_set, size_dots_prediction_set):
    
    n = len(actions)
    data_to_plot = [training_set[i::n] for i in range(n)]
    colors = ["black","slategrey","blue","lightblue","cyan","Green","lightgreen","yellow","brown","orange","red","purple","pink"]
    
    fig = plt.figure(constrained_layout=True)
    gs = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)
    fig = plt.figure(figsize=(20,40))
    
    #### Plot training data + prediction data ####
    
    ax = fig.add_subplot(gs[0, :], projection="3d")
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')

    for i in range(n):
        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        ax.scatter(x,y,z, c=colors[i], s=size_dots_training_set, alpha=0.20, edgecolors="black")

    xpredict, ypredict, zpredict = prediction_set[:,0], prediction_set[:,1], prediction_set[:,2]
    for i in range(n):
        ax.scatter(xpredict[i], ypredict[i], zpredict[i], c=colors[i], label=actions[i], s=size_dots_prediction_set, edgecolors="black")

    ax.legend(loc='center left', prop={'size': 15})    
    ax.set_title("Données d'apprentissage ET données de tests")

    
    
    
    
    #### Plot training data ####

    fig = plt.figure(figsize=(20,20))
    ax2 = fig.add_subplot(gs[1,0], projection="3d")
    ax2.set_xlabel('X Label')
    ax2.set_ylabel('Y Label')
    ax2.set_zlabel('Z Label')
    ax2.set_title("Données d'apprentissage")


    for i in range(n):
        x, y, z = data_to_plot[i][:,0], data_to_plot[i][:,1], data_to_plot[i][:,2]
        ax2.scatter(x,y,z, c=colors[i], label=actions[i], s=size_dots_training_set, alpha=0.20, edgecolors="black")
        ax2.legend(loc='center left', prop={'size': 15})


    
    
    #### prediction data ####

    ax3 = fig.add_subplot(gs[1,1], projection="3d")
    ax3.set_xlabel('X Label')
    ax3.set_ylabel('Y Label')
    ax3.set_zlabel('Z Label')
    ax3.set_title("Données de tests")

    for i in range(13):
        ax3.scatter(xpredict[i], ypredict[i], zpredict[i], c=colors[i], label=actions[i], s=size_dots_prediction_set, edgecolors="black")

    ax3.legend(loc='center left', prop={'size': 15})    

    plt.show()

# %%
plot_training_and_prediction_data3D(training_set, prediction_set, 70, 140)
